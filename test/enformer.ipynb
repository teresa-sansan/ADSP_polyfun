# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-b2252577d0f9> in <module>()
# ----> 1 import tensorflow as tf
#       2 # Make sure the GPU is enabled
#       3 # assert tf.config.list_physical_devices('GPU'), 'Start the colab kernel with GPU: Runtime -> Change runtime type -> GPU'
#
# ~/.local/lib/python3.7/site-packages/tensorflow/__init__.py in <module>()
#      35 import typing as _typing
#      36
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      39
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/__init__.py in <module>()
#      40
#      41 # Bring in subpackages.
# ---> 42 from tensorflow.python import data
#      43 from tensorflow.python import distribute
#      44 # from tensorflow.python import keras
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/data/__init__.py in <module>()
#      19
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/data/experimental/__init__.py in <module>()
#      94
#      95 # pylint: disable=unused-import
# ---> 96 from tensorflow.python.data.experimental import service
#      97 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      98 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/data/experimental/service/__init__.py in <module>()
#     417 """
#     418
# --> 419 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     420 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     421 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/data/experimental/ops/data_service_ops.py in <module>()
#      23 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      24 from tensorflow.python.data.experimental.service import _pywrap_utils
# ---> 25 from tensorflow.python.data.ops import dataset_ops
#      26 from tensorflow.python.data.ops import options as options_lib
#      27 from tensorflow.python.data.ops import structured_function
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in <module>()
#      27 from tensorflow.core.framework import graph_pb2
#      28 from tensorflow.python import tf2
# ---> 29 from tensorflow.python.data.ops import iterator_ops
#      30 from tensorflow.python.data.ops import options as options_lib
#      31 from tensorflow.python.data.ops import structured_function
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py in <module>()
#      32 from tensorflow.python.ops import gen_dataset_ops
#      33 from tensorflow.python.trackable import base as trackable
# ---> 34 from tensorflow.python.training.saver import BaseSaverBuilder
#      35 from tensorflow.python.util import _pywrap_utils
#      36 from tensorflow.python.util import deprecation
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/training/saver.py in <module>()
#      30 from tensorflow.core.protobuf import saver_pb2
#      31 from tensorflow.core.protobuf import trackable_object_graph_pb2
# ---> 32 from tensorflow.python.checkpoint import checkpoint_management
#      33 from tensorflow.python.client import session
#      34 from tensorflow.python.eager import context
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/checkpoint/__init__.py in <module>()
#       1 """API defining checkpoint."""
#       2
# ----> 3 from tensorflow.python.checkpoint import checkpoint_view
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/checkpoint/checkpoint_view.py in <module>()
#      17
#      18 from tensorflow.core.protobuf import trackable_object_graph_pb2
# ---> 19 from tensorflow.python.checkpoint import trackable_view
#      20 from tensorflow.python.framework import errors_impl
#      21 from tensorflow.python.platform import tf_logging as logging
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/checkpoint/trackable_view.py in <module>()
#      18
#      19 from tensorflow.python.trackable import base
# ---> 20 from tensorflow.python.trackable import converter
#      21 from tensorflow.python.util import object_identity
#      22 from tensorflow.python.util.tf_export import tf_export
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/trackable/converter.py in <module>()
#      16
#      17
# ---> 18 from tensorflow.python.eager.polymorphic_function import saved_model_utils
#      19 from tensorflow.python.framework import dtypes
#      20 from tensorflow.python.framework import tensor_util
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/eager/polymorphic_function/saved_model_utils.py in <module>()
#      34 from tensorflow.python.trackable import asset
#      35 from tensorflow.python.trackable import base as trackable
# ---> 36 from tensorflow.python.trackable import resource
#      37
#      38
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/trackable/resource.py in <module>()
#      20
#      21 from tensorflow.python.eager import context
# ---> 22 from tensorflow.python.eager import def_function
#      23 from tensorflow.python.framework import ops
#      24 from tensorflow.python.trackable import base
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in <module>()
#      18
#      19 # Config Options
# ---> 20 from tensorflow.python.eager.polymorphic_function.polymorphic_function import set_dynamic_variable_creation
#      21 from tensorflow.python.eager.polymorphic_function.polymorphic_function import run_functions_eagerly
#      22 from tensorflow.python.eager.polymorphic_function.polymorphic_function import functions_run_eagerly
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in <module>()
#      74 from tensorflow.python.eager import lift_to_graph
#      75 from tensorflow.python.eager import monitoring
# ---> 76 from tensorflow.python.eager.polymorphic_function import function_spec as function_spec_lib
#      77 from tensorflow.python.eager.polymorphic_function import monomorphic_function
#      78 from tensorflow.python.eager.polymorphic_function import tracing_compiler
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/eager/polymorphic_function/function_spec.py in <module>()
#      23
#      24 from tensorflow.core.function import trace_type
# ---> 25 from tensorflow.core.function.polymorphism import function_type as function_type_lib
#      26 from tensorflow.python.eager.polymorphic_function import composite_tensor_utils
#      27 from tensorflow.python.framework import composite_tensor
#
# ~/.local/lib/python3.7/site-packages/tensorflow/core/function/polymorphism/function_type.py in <module>()
#      17 import collections
#      18 import inspect
# ---> 19 from typing import Any, Callable, Dict, Mapping, Optional, Sequence, Tuple, OrderedDict
#      20
#      21 from tensorflow.core.function import trace_type
#
# ImportError: cannot import name 'OrderedDict' from 'typing' (/nfs/sw/jupyter/jupyter3-4.1/lib/python3.7/typing.py)

# %%
from typing import Any,Callable,Dict, Mapping, Optional, Sequence, Tuple
from typing_extensions import OrderedDict

# %%
import tensorflow as tf
# Make sure the GPU is enabled 
# assert tf.config.list_physical_devices('GPU'), 'Start the colab kernel with GPU: Runtime -> Change runtime type -> GPU'
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-b2252577d0f9> in <module>()
# ----> 1 import tensorflow as tf
#       2 # Make sure the GPU is enabled
#       3 # assert tf.config.list_physical_devices('GPU'), 'Start the colab kernel with GPU: Runtime -> Change runtime type -> GPU'
#
# ~/.local/lib/python3.7/site-packages/tensorflow/__init__.py in <module>()
#      35 import typing as _typing
#      36
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      39
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/__init__.py in <module>()
#      40
#      41 # Bring in subpackages.
# ---> 42 from tensorflow.python import data
#      43 from tensorflow.python import distribute
#      44 # from tensorflow.python import keras
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/data/__init__.py in <module>()
#      19
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/data/experimental/__init__.py in <module>()
#      94
#      95 # pylint: disable=unused-import
# ---> 96 from tensorflow.python.data.experimental import service
#      97 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      98 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/data/experimental/service/__init__.py in <module>()
#     417 """
#     418
# --> 419 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     420 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     421 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/data/experimental/ops/data_service_ops.py in <module>()
#      23 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      24 from tensorflow.python.data.experimental.service import _pywrap_utils
# ---> 25 from tensorflow.python.data.ops import dataset_ops
#      26 from tensorflow.python.data.ops import options as options_lib
#      27 from tensorflow.python.data.ops import structured_function
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in <module>()
#      27 from tensorflow.core.framework import graph_pb2
#      28 from tensorflow.python import tf2
# ---> 29 from tensorflow.python.data.ops import iterator_ops
#      30 from tensorflow.python.data.ops import options as options_lib
#      31 from tensorflow.python.data.ops import structured_function
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py in <module>()
#      32 from tensorflow.python.ops import gen_dataset_ops
#      33 from tensorflow.python.trackable import base as trackable
# ---> 34 from tensorflow.python.training.saver import BaseSaverBuilder
#      35 from tensorflow.python.util import _pywrap_utils
#      36 from tensorflow.python.util import deprecation
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/training/saver.py in <module>()
#      30 from tensorflow.core.protobuf import saver_pb2
#      31 from tensorflow.core.protobuf import trackable_object_graph_pb2
# ---> 32 from tensorflow.python.checkpoint import checkpoint_management
#      33 from tensorflow.python.client import session
#      34 from tensorflow.python.eager import context
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/checkpoint/__init__.py in <module>()
#       1 """API defining checkpoint."""
#       2
# ----> 3 from tensorflow.python.checkpoint import checkpoint_view
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/checkpoint/checkpoint_view.py in <module>()
#      17
#      18 from tensorflow.core.protobuf import trackable_object_graph_pb2
# ---> 19 from tensorflow.python.checkpoint import trackable_view
#      20 from tensorflow.python.framework import errors_impl
#      21 from tensorflow.python.platform import tf_logging as logging
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/checkpoint/trackable_view.py in <module>()
#      18
#      19 from tensorflow.python.trackable import base
# ---> 20 from tensorflow.python.trackable import converter
#      21 from tensorflow.python.util import object_identity
#      22 from tensorflow.python.util.tf_export import tf_export
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/trackable/converter.py in <module>()
#      16
#      17
# ---> 18 from tensorflow.python.eager.polymorphic_function import saved_model_utils
#      19 from tensorflow.python.framework import dtypes
#      20 from tensorflow.python.framework import tensor_util
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/eager/polymorphic_function/saved_model_utils.py in <module>()
#      34 from tensorflow.python.trackable import asset
#      35 from tensorflow.python.trackable import base as trackable
# ---> 36 from tensorflow.python.trackable import resource
#      37
#      38
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/trackable/resource.py in <module>()
#      20
#      21 from tensorflow.python.eager import context
# ---> 22 from tensorflow.python.eager import def_function
#      23 from tensorflow.python.framework import ops
#      24 from tensorflow.python.trackable import base
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in <module>()
#      18
#      19 # Config Options
# ---> 20 from tensorflow.python.eager.polymorphic_function.polymorphic_function import set_dynamic_variable_creation
#      21 from tensorflow.python.eager.polymorphic_function.polymorphic_function import run_functions_eagerly
#      22 from tensorflow.python.eager.polymorphic_function.polymorphic_function import functions_run_eagerly
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in <module>()
#      74 from tensorflow.python.eager import lift_to_graph
#      75 from tensorflow.python.eager import monitoring
# ---> 76 from tensorflow.python.eager.polymorphic_function import function_spec as function_spec_lib
#      77 from tensorflow.python.eager.polymorphic_function import monomorphic_function
#      78 from tensorflow.python.eager.polymorphic_function import tracing_compiler
#
# ~/.local/lib/python3.7/site-packages/tensorflow/python/eager/polymorphic_function/function_spec.py in <module>()
#      23
#      24 from tensorflow.core.function import trace_type
# ---> 25 from tensorflow.core.function.polymorphism import function_type as function_type_lib
#      26 from tensorflow.python.eager.polymorphic_function import composite_tensor_utils
#      27 from tensorflow.python.framework import composite_tensor
#
# ~/.local/lib/python3.7/site-packages/tensorflow/core/function/polymorphism/function_type.py in <module>()
#      17 import collections
#      18 import inspect
# ---> 19 from typing import Any, Callable, Dict, Mapping, Optional, Sequence, Tuple, OrderedDict
#      20
#      21 from tensorflow.core.function import trace_type
#
# ImportError: cannot import name 'OrderedDict' from 'typing' (/nfs/sw/jupyter/jupyter3-4.1/lib/python3.7/typing.py)

# %%
cannot import name 'OrderedDict' from 'typing' (/nfs/sw/jupyter/jupyter3-4.1/lib/python3.7/typing.py)
import pandas as pd

# %%
import pandas as pd

# %%
# !python --version
# Out:
# Python 3.9.16

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (2.10.0)
# Requirement already satisfied: six>=1.12.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Collecting protobuf<3.20,>=3.9.2
#   Using cached protobuf-3.19.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (2.10.0)
# Collecting libclang>=13.0.0
#   Using cached libclang-15.0.6.1-py2.py3-none-manylinux2010_x86_64.whl (21.5 MB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.30.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 19.9 MB/s eta 0:00:00:00:01
# Requirement already satisfied: packaging in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (22.0)
# Requirement already satisfied: wrapt>=1.11.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: termcolor>=1.1.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: astunparse>=1.6.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: setuptools in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (65.6.3)
# Requirement already satisfied: numpy>=1.20 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.6.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.2.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (4.11.3)
# Requirement already satisfied: certifi>=2017.4.17 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.1)
# Installing collected packages: libclang, tensorflow-io-gcs-filesystem, protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.1
#     Uninstalling protobuf-3.20.1:
#       Successfully uninstalled protobuf-3.20.1
# Successfully installed libclang-15.0.6.1 protobuf-3.19.6 tensorflow-io-gcs-filesystem-0.30.0

# %%
import sys
print(sys.executable)
! /nfs/sw/jupyter/jupyter3-4.1/bin/python -m pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Downloading tensorflow-2.11.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (588.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.3/588.3 MB 5.4 MB/s eta 0:00:0000:0100:01
# Collecting six>=1.12.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.14.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.2/75.2 kB 2.5 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.30.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 14.2 MB/s eta 0:00:0000:01
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: setuptools in /nfs/sw/jupyter/jupyter3-4.1/lib/python3.7/site-packages (from tensorflow) (40.2.0)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 14.0 MB/s eta 0:00:0000:01
# Collecting libclang>=13.0.0
#   Downloading libclang-15.0.6.1-py2.py3-none-manylinux2010_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 35.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions>=3.6.6 in /nfs/sw/jupyter/jupyter3-4.1/lib/python3.7/site-packages (from tensorflow) (4.4.0)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.51.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 30.7 MB/s eta 0:00:0000:0100:01
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 2.4 MB/s eta 0:00:00
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /nfs/sw/jupyter/jupyter3-4.1/lib/python3.7/site-packages (from tensorflow) (17.1)
# Collecting tensorboard<2.12,>=2.11
#   Downloading tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 30.4 MB/s eta 0:00:0000:0100:01
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-23.1.21-py2.py3-none-any.whl (26 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.2.0-py3-none-any.whl (6.6 kB)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 21.4 MB/s eta 0:00:0000:0100:01
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 kB 5.9 MB/s eta 0:00:0000:01
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting keras<2.12,>=2.11.0
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 13.0 MB/s eta 0:00:0000:01
# Requirement already satisfied: numpy>=1.20 in /gpfs/commons/home/tlin/.local/lib/python3.7/site-packages (from tensorflow) (1.21.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /nfs/sw/jupyter/jupyter3-4.1/lib/python3.7/site-packages (from astunparse>=1.6.0->tensorflow) (0.31.1)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 7.6 MB/s eta 0:00:0000:01
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.16.0-py2.py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.8/177.8 kB 19.7 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 kB 9.4 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 13.7 MB/s eta 0:00:00
# Collecting setuptools
#   Downloading setuptools-67.0.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 8.6 MB/s eta 0:00:00:00:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 27.8 MB/s eta 0:00:0000:0100:01
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.0.2 in /nfs/sw/jupyter/jupyter3-4.1/lib/python3.7/site-packages (from packaging->tensorflow) (2.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /nfs/sw/jupyter/jupyter3-4.1/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.2)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-6.0.0-py3-none-any.whl (21 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (170 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 kB 22.2 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /nfs/sw/jupyter/jupyter3-4.1/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2018.8.24)
# Requirement already satisfied: idna<4,>=2.5 in /nfs/sw/jupyter/jupyter3-4.1/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /nfs/sw/jupyter/jupyter3-4.1/lib/python3.7/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.23)
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.12.0-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.1 in /nfs/sw/jupyter/jupyter3-4.1/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.4)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 15.3 MB/s eta 0:00:00
# Installing collected packages: tensorboard-plugin-wit, libclang, flatbuffers, charset-normalizer, zipp, wrapt, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, six, setuptools, rsa, requests, protobuf, opt-einsum, oauthlib, MarkupSafe, keras, h5py, grpcio, gast, cachetools, absl-py, werkzeug, requests-oauthlib, importlib-metadata, google-pasta, google-auth, astunparse, markdown, google-auth-oauthlib, tensorboard, tensorflow
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# Successfully installed MarkupSafe-2.1.2 absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.0 charset-normalizer-3.0.1 flatbuffers-23.1.21 gast-0.4.0 google-auth-2.16.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.51.1 h5py-3.8.0 importlib-metadata-6.0.0 keras-2.11.0 libclang-15.0.6.1 markdown-3.4.1 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-3.19.6 requests-2.28.2 requests-oauthlib-1.3.1 rsa-4.9 setuptools-67.0.0 six-1.16.0 tensorboard-2.11.2 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-io-gcs-filesystem-0.30.0 termcolor-2.2.0 werkzeug-2.2.2 wrapt-1.14.1 zipp-3.12.0
#
# [notice] A new release of pip available: 22.3 -> 23.0
# [notice] To update, run: /nfs/sw/jupyter/jupyter3-4.1/bin/python -m pip install --upgrade pip

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (2.4.1)
# Requirement already satisfied: flatbuffers~=1.12.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: grpcio~=1.32.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (1.32.0)
# Requirement already satisfied: google-pasta~=0.2 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wrapt~=1.12.1 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: h5py~=2.10.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: tensorboard~=2.4 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: protobuf>=3.9.2 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: termcolor~=1.1.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: numpy~=1.19.2 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: opt-einsum~=3.3.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: astunparse~=1.6.3 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: wheel~=0.35 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: gast==0.3.3 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: six~=1.15.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: absl-py~=0.10 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (0.15.0)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (1.8.1)
# Requirement already satisfied: setuptools>=41.0.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (65.6.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (2.28.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (2.2.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (2.6.0)
# Requirement already satisfied: markdown>=2.6.8 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from tensorboard~=2.4->tensorflow) (0.4.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow) (4.11.3)
# Requirement already satisfied: idna<4,>=2.5 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard~=2.4->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.4->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /gpfs/commons/home/tlin/miniconda3/envs/tensorflow/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (3.2.1)
