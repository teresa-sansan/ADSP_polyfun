# %%
import pandas as pd

path='/gpfs/commons/home/tlin/output/cT/kunkle/fixed_0224/subsets/qc_on_variant_sumstat/'
save_name='kunkle/fixed_0224/remove_APOE_qc_on_variant_sumstat.tsv'

sumstat=["bellenguez","kunkle","wightman"]
plink=["ADSP","ADSP_qc_all","ADSP_qc_variant","ADSP_UKBB","ADSP_UKBB_qc"]
# sumstat = ['wightman']
# plink = ['ADSP']

for x in sumstat:
 for y in plink:
  path = '/gpfs/commons/home/tlin/output/cT/genomewide_plink/'+ x + '/' + y + '/'
  
  save_name = x + '/' + x + "_" + y 
  prs_e5 = pd.read_csv(path+"pT_e-5.prs", sep = ' ', names = ["IID","PRS"])
  prs_001 = pd.read_csv(path+"pT_0.001.prs", sep = ' ', names = ["IID","PRS"])
  prs_005 = pd.read_csv(path+"pT_0.005.prs", sep = ' ', names = ["IID","PRS"])   
  prs_01 = pd.read_csv(path+"pT_0.01.prs", sep = ' ', names = ["IID","PRS"]) 
  prs_05 = pd.read_csv(path+"pT_0.05.prs", sep = ' ', names = ["IID","PRS"])
  prs_1 = pd.read_csv(path+"pT_0.1.prs", sep = ' ', names = ["IID","PRS"]) 
  prs_5 = pd.read_csv(path+"pT_0.5.prs", sep = ' ', names = ["IID","PRS"]) 

  pheno = pd.read_csv("/gpfs/commons/groups/knowles_lab/data/ADSP_reguloML/ADSP_vcf/compact_filtered_vcf_16906/phenotype_data_10_28_2021/all_phenotypes_unique_ancestry_subset.tsv", sep='\t')
  prs = [prs_e5, prs_001, prs_005, prs_01, prs_05, prs_1, prs_5]  
  from functools import reduce  
  prs_merge = reduce(lambda left, right:pd.merge(left,right,on=["IID"]),prs)

  prs_merge = prs_merge.set_axis( ["IID","PRS_e5","PRS_001","PRS_005","PRS_01","PRS_05","PRS_1","PRS_5"], axis='columns')
  all_merge = pd.merge(pheno,prs_merge, left_on ="SampleID", right_on='IID')
  all_merge.fillna('-1', inplace=True)  # Race and Ethniciity
  save="/gpfs/commons/home/tlin/output/prs/new_plink/"+ save_name+'.tsv'
  #all_merge.to_csv(save,index = False, sep='\t')
  print(all_merge[all_merge.age_covariate < 40].shape)
  print("save prs to " + save)
# Out:
# (9, 40)
# save prs to /gpfs/commons/home/tlin/output/prs/new_plink/bellenguez/bellenguez_ADSP.tsv
# (7, 40)
# save prs to /gpfs/commons/home/tlin/output/prs/new_plink/bellenguez/bellenguez_ADSP_qc_all.tsv
# (9, 40)
# save prs to /gpfs/commons/home/tlin/output/prs/new_plink/bellenguez/bellenguez_ADSP_qc_variant.tsv
# (9, 40)
# save prs to /gpfs/commons/home/tlin/output/prs/new_plink/bellenguez/bellenguez_ADSP_UKBB.tsv
# (7, 40)
# save prs to /gpfs/commons/home/tlin/output/prs/new_plink/bellenguez/bellenguez_ADSP_UKBB_qc.tsv
# (9, 40)
# save prs to /gpfs/commons/home/tlin/output/prs/new_plink/kunkle/kunkle_ADSP.tsv
# (7, 40)
# save prs to /gpfs/commons/home/tlin/output/prs/new_plink/kunkle/kunkle_ADSP_qc_all.tsv
# (9, 40)
# save prs to /gpfs/commons/home/tlin/output/prs/new_plink/kunkle/kunkle_ADSP_qc_variant.tsv
# (9, 40)
# save prs to /gpfs/commons/home/tlin/output/prs/new_plink/kunkle/kunkle_ADSP_UKBB.tsv
# (7, 40)
# save prs to /gpfs/commons/home/tlin/output/prs/new_plink/kunkle/kunkle_ADSP_UKBB_qc.tsv
# (9, 40)
# save prs to /gpfs/commons/home/tlin/output/prs/new_plink/wightman/wightman_ADSP.tsv
# (7, 40)
# save prs to /gpfs/commons/home/tlin/output/prs/new_plink/wightman/wightman_ADSP_qc_all.tsv
# (9, 40)
# save prs to /gpfs/commons/home/tlin/output/prs/new_plink/wightman/wightman_ADSP_qc_variant.tsv
# (9, 40)
# save prs to /gpfs/commons/home/tlin/output/prs/new_plink/wightman/wightman_ADSP_UKBB.tsv
# (7, 40)
# save prs to /gpfs/commons/home/tlin/output/prs/new_plink/wightman/wightman_ADSP_UKBB_qc.tsv

# %%
all_merge.shape
# Out:
# (13265, 40)

# %%
all_merge.isnull().sum()
# Out:
# SUBJID                  0
# SampleID                0
# cohort                  0
# Sex                     0
# APOE                    0
# Race                   16
# Ethnicity             104
# AD_status_final         0
# age_covariate           0
# flag_age_covariate      0
# Duplicate_SUBJID        0
# final_population        0
# X1                      0
# X2                      0
# X3                      0
# X4                      0
# X5                      0
# X6                      0
# X7                      0
# X8                      0
# X9                      0
# X10                     0
# X11                     0
# X12                     0
# X13                     0
# X14                     0
# X15                     0
# X16                     0
# X17                     0
# X18                     0
# X19                     0
# X20                     0
# IID                     0
# PRS_e5                  0
# PRS_001                 0
# PRS_005                 0
# PRS_01                  0
# PRS_05                  0
# PRS_1                   0
# PRS_5                   0
# dtype: int64

# %%
all_merge.fillna('-1', inplace=True)
all_merge
# Out:
#                 SUBJID                           SampleID      cohort  Sex  \
# 0      ADNI_002_S_0685                    ADNI_002_S_0685        ADNI    1
# 1      ADNI_002_S_0729                    ADNI_002_S_0729        ADNI    1
# 2      ADNI_002_S_1155                    ADNI_002_S_1155        ADNI    0
# 3      ADNI_002_S_1261                    ADNI_002_S_1261        ADNI    1
# 4      ADNI_002_S_1280                    ADNI_002_S_1280        ADNI    1
# ...                ...                                ...         ...  ...
# 13260   A-MIA-UM001891     A-MIA-UM001891-BL-MIA-19881206  ADSPFamily    0
# 13261   A-MIA-UM001948  A-MIA-UM001948-BR-MIA-201307290uf  ADSPFamily    1
# 13262   A-MIA-UM001977    A-MIA-UM001977-BR-MIA-201307285  ADSPFamily    1
# 13263   A-MIA-UM009108    A-MIA-UM009108-BR-MIA-201335871  ADSPFamily    1
# 13264   A-RAS-RA000011     A-RAS-RA000011-UNK-UNK-UNK0001  ADSPFamily    1
#
#        APOE Race Ethnicity  AD_status_final  age_covariate  \
# 0        33    5         0                0             90
# 1        34    5         0                1             68
# 2        33    5         0                0             69
# 3        33    5         0                0             82
# 4        34    5         1                0             81
# ...     ...  ...       ...              ...            ...
# 13260    34    5         0                1             64
# 13261    33    5         0                1             69
# 13262    33    5         0                1             71
# 13263    34    5         0                1             82
# 13264    34    5         0                1             85
#
#        flag_age_covariate  ...       X19       X20  \
# 0                       1  ...  0.716141 -3.876558
# 1                       1  ... -0.392832  0.123630
# 2                       1  ... -1.563714  0.953809
# 3                       1  ... -1.916193 -1.545018
# 4                       1  ...  1.274743  0.348920
# ...                   ...  ...       ...       ...
# 13260                   1  ... -1.468883  0.948126
# 13261                   1  ... -2.721241  2.054853
# 13262                   1  ...  0.250296  1.222130
# 13263                   1  ... -0.329476  2.267419
# 13264                   1  ...  1.333406  1.465154
#
#                                      IID   PRS_e5   PRS_001   PRS_005  \
# 0                        ADNI_002_S_0685  2.37338  0.918023  0.458066
# 1                        ADNI_002_S_0729  2.61385  0.914541  0.451994
# 2                        ADNI_002_S_1155  2.41503  0.866181  0.442862
# 3                        ADNI_002_S_1261  3.06060  0.904114  0.452775
# 4                        ADNI_002_S_1280  2.85702  0.902102  0.449360
# ...                                  ...      ...       ...       ...
# 13260     A-MIA-UM001891-BL-MIA-19881206  2.83669  0.903668  0.452354
# 13261  A-MIA-UM001948-BR-MIA-201307290uf  1.29649  0.838311  0.435528
# 13262    A-MIA-UM001977-BR-MIA-201307285  1.86693  0.913900  0.453652
# 13263    A-MIA-UM009108-BR-MIA-201335871  1.81946  0.861135  0.439057
# 13264     A-RAS-RA000011-UNK-UNK-UNK0001  2.02061  0.847108  0.433363
#
#          PRS_01    PRS_05     PRS_1     PRS_5
# 0      0.305415  0.102165  0.059009  0.015087
# 1      0.301722  0.101496  0.058674  0.015033
# 2      0.295476  0.099535  0.057527  0.014681
# 3      0.301639  0.101329  0.058574  0.014994
# 4      0.298148  0.100079  0.057847  0.014768
# ...         ...       ...       ...       ...
# 13260  0.301716  0.101926  0.058956  0.015115
# 13261  0.292626  0.099297  0.057455  0.014692
# 13262  0.301779  0.101697  0.058852  0.015075
# 13263  0.293056  0.098679  0.057022  0.014524
# 13264  0.291294  0.098962  0.057182  0.014615
#
# [13265 rows x 40 columns]

# %%
all_merge.isnull().sum()
# Out:
# SUBJID                0
# SampleID              0
# cohort                0
# Sex                   0
# APOE                  0
# Race                  0
# Ethnicity             0
# AD_status_final       0
# age_covariate         0
# flag_age_covariate    0
# Duplicate_SUBJID      0
# final_population      0
# X1                    0
# X2                    0
# X3                    0
# X4                    0
# X5                    0
# X6                    0
# X7                    0
# X8                    0
# X9                    0
# X10                   0
# X11                   0
# X12                   0
# X13                   0
# X14                   0
# X15                   0
# X16                   0
# X17                   0
# X18                   0
# X19                   0
# X20                   0
# IID                   0
# PRS_e5                0
# PRS_001               0
# PRS_005               0
# PRS_01                0
# PRS_05                0
# PRS_1                 0
# PRS_5                 0
# dtype: int64

# %%
test=pd.read_csv('/gpfs/commons/home/tlin/output/prs/new_plink/wightman/wightman_ADSP.tsv', sep = '\t')

# %%
test[test.age_covariate < 40].shape
# Out:
# (9, 40)

# %%
all_merge
