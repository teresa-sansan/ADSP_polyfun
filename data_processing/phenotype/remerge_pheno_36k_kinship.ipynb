# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
## load data
path = '/gpfs/commons/groups/knowles_lab/data/ADSP_reguloML/ADSP_vcf/phenotype_file/release_36K/'
SUBJ_drop = pd.read_excel(path + 'ng00067_subject_droplist_2022.08.18.xlsx', engine = 'openpyxl') ## Note: This one is for 17k

manifest = pd.read_csv(path + "SampleManifest_DS_2022.08.18_ALL.txt", sep='\t') ## the one with mapping info
pheno_sampleID = pd.read_csv(path + "pheno_merge_sampleID.tsv", sep='\t')
pheno_merge = pd.read_csv(path + 'phenotype_merged.tsv', sep = '\t')
king = np.loadtxt("/gpfs/commons/groups/knowles_lab/data/ADSP_reguloML/ADSP_vcf/phenotype_file/release_36K/unrelated_samples.txt", dtype=str) ## The non-related individual's sample ID calculate from Kinship only have sample ID
king_duplicate = pd.read_csv('/gpfs/commons/groups/knowles_lab/data/ADSP_reguloML/ADSP_vcf/phenotype_file/release_36K/duplicate_vcf.txt', sep = '\t')

# %%
king.shape
# Out:
# (33572,)

# %%
manifest[manifest.SampleID.isin(king)].shape
# Out:
# (33572, 10)

# %%
pheno_w_sampleID = pd.read_csv(path+'pheno_merge_sampleID_king.tsv', sep = '\t')

# %%
manifest[manifest.SampleID.isin(king)].value_counts('SUBJID').max()
# Out:
# 1

# %%
pheno_merge.columns
# Out:
# Index(['SUBJID', 'Sex', 'Age', 'Age_baseline', 'APOE_reported', 'Race',
#        'Diagnosis', 'source'],
#       dtype='object')

# %%
king[np.isin(king, manifest.SampleID)].shape
# Out:
# (33572,)

# %%
pheno_sampleID.shape
# Out:
# (36246, 17)

# %% [markdown]
# ### Take the intersection of Manifest file and the king

# %%
manifest_king = manifest[manifest.SampleID.isin(king)] 
manifest_king.shape
# Out:
# (33572, 10)

# %%
manifest_king[manifest_king.SUBJID.isin(pheno_merge.SUBJID)].shape ## this is worrysome!
# Out:
# (20058, 10)

# %%
manifest[manifest.SUBJID.isin(pheno_merge.SUBJID)].shape
# Out:
# (40646, 10)

# %%
king_duplicate[king_duplicate.ID2.isin(manifest.SampleID)].shape
# Out:
# (1602, 9)

# %%
king_duplicate[king_duplicate.ID1.isin(manifest.SampleID)].shape
# Out:
# (1602, 9)

# %%
king_duplicate[king_duplicate.ID2.isin(king)].shape
# Out:
# (25, 9)

# %%
king_duplicate[king_duplicate.ID1.isin(king)].shape
# Out:
# (1212, 9)

# %%
king_duplicate[(king_duplicate.ID1.isin(king)) | (king_duplicate.ID2.isin(king))]
# Out:
#                                     ID1                                ID2  \
# 0      A-ADC-AD000017-BR-NCR-10AD30552e  A-ADC-AD000017-BR-NCR-10AD30552uf
# 1       A-ADC-AD000151-BR-NCR-09AD14539   A-ADC-AD000151-BR-NCR-09AD14539g
# 2        A-ADC-AD000492-BR-NCR-08AD9077    A-ADC-AD000492-BR-NCR-08AD9077g
# 3     A-ADC-AD000862-BL-NCR-09AD16175uf    A-LOAD-LD001749-BL-NCR-07AD2157
# 4       A-ADC-AD000322-BR-NCR-09AD12231       A-PITT-PT000001-BL-UPT-a0011
# ...                                 ...                                ...
# 1597       P-UCLA-LA000444-UNK-UPN-2227         P-UPN-PSP8396-UNK-UPN-2230
# 1598         P-UPN-PSP8397-UNK-UPN-2214      P-UPN-PSP10695-UNK-UPN-108077
# 1599       P-UPN-PSP10108-BL-UPN-117566      P-UPN-PSP10108-UNK-UPN-117566
# 1600       P-UPN-PSP10123-BL-UPN-119413      P-UPN-PSP10123-UNK-UPN-119413
# 1601         P-UPN-PSP8399-UNK-UPN-2202      P-UPN-PSP10698-UNK-UPN-112570
#
#            N  N_IBS0  N_IBS1  N_IBS2  Concord  HomConc  HetConc
# 0     412479      33    2557  409889  0.99372  0.99989  0.97879
# 1     404051      35    5171  398845  0.98712  0.99988  0.95206
# 2     404641      66    4848  399727  0.98786  0.99977  0.95813
# 3     411235      35    3121  408079  0.99233  0.99988  0.97288
# 4     412005      30    2396  409579  0.99411  0.99990  0.97909
# ...      ...     ...     ...     ...      ...      ...      ...
# 1597  411260      60    3084  408116  0.99236  0.99980  0.97296
# 1598  411151      44    2757  408350  0.99319  0.99985  0.97585
# 1599  411558      46    3397  408115  0.99163  0.99985  0.97009
# 1600  411711      39    2886  408786  0.99290  0.99987  0.97469
# 1601  411444      39    2848  408557  0.99298  0.99987  0.97481
#
# [1237 rows x 9 columns]

# %%
king_duplicate[(~king_duplicate.ID1.isin(king)) & (~king_duplicate.ID2.isin(king))]
# Out:
#                                        ID1  \
# 9          A-ADC-AD000492-BR-NCR-08AD9077g
# 18         A-ADC-AD001697-BR-NCR-08AD10470
# 19          A-ADC-AD001227-BR-NCR-08AD8251
# 32          A-ADC-AD001810-BR-NCR-08AD9168
# 41         A-ADC-AD003178-BL-NCR-09AD16068
# ...                                    ...
# 1484  A-NCRD-NC005389-BR-NCR-91M0544u1-B01
# 1485  A-NCRD-NC005389-BR-NCR-91M0544u2-H08
# 1513     A-TARC-TC001429-BL-NCR-0005802871
# 1528      G-ADNI-AN000150-BL-NCR-12AD54510
# 1531      G-KGAD-KA001030-BL-WU-8038741633
#
#                                        ID2       N  N_IBS0  N_IBS1  N_IBS2  \
# 9        G-KGAD-KA000111-UNK-WU-8038741595  404647      67    4894  399686
# 18         A-MIA-UM000320-BR-MIA-201307287  410429      58    3888  406483
# 19         A-MIA-UM009149-BR-MIA-201335872  411894      65    2437  409392
# 32          A-MIA-UM001979-BL-MIA-19881664  410305      64    3407  406834
# 41         A-LOAD-LD001526-UNK-UNK-UNK0019  409689      62    3961  405666
# ...                                    ...     ...     ...     ...     ...
# 1484  A-NCRD-NC005389-BR-NCR-91M0544u3-H08  411739      46    2531  409162
# 1485  A-NCRD-NC005389-BR-NCR-91M0544u3-H08  411620      38    2816  408766
# 1513     A-TARC-TC001745-BL-NCR-0005802867  411900      68   20814  391018
# 1528     G-KGAD-KA000058-UNK-WU-8005871893  411281      45    3365  407871
# 1531     G-KGAD-KA001030-UNK-WU-8038741581  411300      27    2621  408652
#
#       Concord  HomConc  HetConc
# 9     0.98774  0.99977  0.95775
# 18    0.99039  0.99981  0.96551
# 19    0.99393  0.99978  0.97878
# 32    0.99154  0.99979  0.96827
# 41    0.99018  0.99979  0.96562
# ...       ...      ...      ...
# 1484  0.99374  0.99984  0.97968
# 1485  0.99307  0.99987  0.97740
# 1513  0.94930  0.99976  0.83510
# 1528  0.99171  0.99985  0.97116
# 1531  0.99356  0.99991  0.97762
#
# [365 rows x 9 columns]

# %% [markdown]
# ### Remove the SUBJID that is in SUBJ_drop

# %%
## the only two rows in manifest file that got removed because appearing in SUBJ_drop
print(manifest[(manifest.SUBJID.isin(pheno_merge.SUBJID)) & (manifest.SUBJID.isin(SUBJ_drop.SUBJID))])
print(manifest.shape)
# Out:
#                SUBJID                         SampleID BODY_SITE ANALYTE_TYPE  \
# 12879  A-MIA-UM000315  A-MIA-UM000315-UNK-MIA-19961724   Unknown          DNA
# 12954  A-MIA-UM001976  A-MIA-UM001976-UNK-MIA-20010205   Unknown          DNA
#
#       Sequencing_Center       Sequencing_Platform SAMPLE_USE  \
# 12879           UM_HIHG  Illumina_HiSeq_2000/2500        WES
# 12954           UM_HIHG  Illumina_HiSeq_2000/2500        WES
#
#        Technical_Replicate Study_DSS Sample_Set
# 12879                    0  sa000006   snd10006
# 12954                    0  sa000006   snd10006
# (56863, 10)

# %%
king_duplicate = king_duplicate.drop(columns = ["FID1", "FID2"])

# %%
manifest[(manifest.SUBJID.duplicated(keep=False))].value_counts('SUBJID') ## total row: 8704
# Out:
# SUBJID
# A-CUHS-CU001166    13
# A-CUHS-CU001163    13
# A-CUHS-CU001167    12
# A-CUHS-CU009833    10
# A-NCRD-NC005389    10
#                    ..
# A-MIA-UM009708      2
# A-MIA-UM009707      2
# A-MIA-UM009706      2
# A-MIA-UM009705      2
# A-ACT-AC000014      2
# Length: 4306, dtype: int64

# %% [markdown]
# ### Take the intersection with King

# %%
manifest[manifest.SampleID.isin(king)].shape
# Out:
# (20058, 10)

# %%
manifest[manifest.SampleID.isin(king)].shape
# Out:
# (20058, 10)

# %%
king.shape
# Out:
# (33572,)

# %%
from_king = manifest[(manifest.SUBJID.duplicated(keep=False))& manifest.SampleID.isin(king)] ## 3987 of the 4306 duplicated SUBJID were found in King

# %%
from_king.shape
# Out:
# (3987, 10)

# %%
manifest[manifest.SampleID.isin(king)].shape
# Out:
# (33572, 10)

# %%
manifest[manifest.SampleID.isin(king)]
# Out:
#                 SUBJID                         SampleID BODY_SITE  \
# 20504  A-LOAD-LD004558  A-LOAD-LD004558-BL-NCR-04AD6349     Blood
# 20509  A-LOAD-LD006391  A-LOAD-LD006391-BR-NCR-03AD5040     Brain
# 20510  A-LOAD-LD006392  A-LOAD-LD006392-BR-NCR-03AD5039     Brain
# 20511  A-LOAD-LD006393  A-LOAD-LD006393-BR-NCR-05AD8062     Brain
# 20516   A-MIA-UM000311  A-MIA-UM000311-BR-MIA-201307291     Brain
# ...                ...                              ...       ...
# 56840   A-ADC-AD013032  A-ADC-AD013032-BL-NCR-15AD81841     Blood
# 56841   A-ADC-AD015544  A-ADC-AD015544-BL-NCR-16AD86202     Blood
# 56842   A-ADC-AD015476  A-ADC-AD015476-BL-NCR-13AD59678     Blood
# 56843   A-ADC-AD015266  A-ADC-AD015266-BR-NCR-14AD74741     Brain
# 56844   A-ADC-AD002607  A-ADC-AD002607-BR-NCR-08AD10805     Brain
#
#       ANALYTE_TYPE Sequencing_Center  Sequencing_Platform SAMPLE_USE  \
# 20504          DNA             WashU  Illumina_HiSeq_2000        WGS
# 20509          DNA             WashU  Illumina_HiSeq_2000        WGS
# 20510          DNA             WashU  Illumina_HiSeq_2000        WGS
# 20511          DNA             WashU  Illumina_HiSeq_2000        WGS
# 20516          DNA             Broad  Illumina_HiSeq_2000        WGS
# ...            ...               ...                  ...        ...
# 56840          DNA             USUHS     Illumina_NovaSeq        WGS
# 56841          DNA             USUHS     Illumina_NovaSeq        WGS
# 56842          DNA             USUHS     Illumina_NovaSeq        WGS
# 56843          DNA             USUHS     Illumina_NovaSeq        WGS
# 56844          DNA             USUHS     Illumina_NovaSeq        WGS
#
#        Technical_Replicate Study_DSS Sample_Set
# 20504                    0  sa000001   snd10000
# 20509                    0  sa000001   snd10000
# 20510                    0  sa000001   snd10000
# 20511                    0  sa000001   snd10000
# 20516                    0  sa000001   snd10000
# ...                    ...       ...        ...
# 56840                    0  sa000001   snd10031
# 56841                    0  sa000001   snd10031
# 56842                    0  sa000001   snd10031
# 56843                    0  sa000001   snd10031
# 56844                    0  sa000001   snd10031
#
# [20058 rows x 10 columns]

# %%
manifest[(manifest.SUBJID.duplicated(keep=False)) & ~manifest.SampleID.isin(king)].value_counts('SUBJID')
# Out:
# SUBJID
# A-CUHS-CU001166    13
# A-CUHS-CU001163    12
# A-CUHS-CU001167    12
# A-NCRD-NC005389     9
# A-CUHS-CU009833     9
#                    ..
# A-MIA-UM009552      1
# A-MIA-UM009551      1
# A-MIA-UM009550      1
# A-MIA-UM009549      1
# A-ACT-AC000014      1
# Length: 4776, dtype: int64

# %% [markdown]
# ## deal with the duplicates outside of the intersection (Shouldn't be any duplicate in the intersection)

# %%
dup_notfindinking = manifest[(manifest.SUBJID.duplicated(keep=False))& ~(manifest.SampleID.isin(king))]

# %%
dup_notfindinking = dup_notfindinking.groupby(['SUBJID']).filter(lambda x: len(x) > 1)

# %%
## extract the WGS one if theres one
print(dup_notfindinking.value_counts('SAMPLE_USE'))
print()
len(dup_notfindinking[dup_notfindinking.SAMPLE_USE == 'WGS'].groupby(['SUBJID']).filter(lambda x: len(x) > 1).SUBJID.unique())
# Out:
# SAMPLE_USE
# WES    518
# WGS    235
# dtype: int64
# 30

# %%
dup_notfindinking[dup_notfindinking.SAMPLE_USE == 'WGS'].groupby(['SUBJID']).filter(lambda x: len(x) > 1)
# Out:
#                 SUBJID                               SampleID BODY_SITE  \
# 20515   A-MIA-UM000037         A-MIA-UM000037-BR-MIA-19890652     Brain
# 20521   A-MIA-UM000463        A-MIA-UM000463-BR-MIA-201307288     Brain
# 20522   A-MIA-UM000474        A-MIA-UM000474-BR-MIA-201307282     Brain
# 20523   A-MIA-UM000477        A-MIA-UM000477-BR-MIA-201307292     Brain
# 20527   A-MIA-UM001127        A-MIA-UM001127-BL-MIA-200426255     Blood
# ...                ...                                    ...       ...
# 56858  A-LOAD-LD004371  A-LOAD-LD004371-BL-NCR-04AD7188u2-H07     Blood
# 56859  A-LOAD-LD004371  A-LOAD-LD004371-BL-NCR-04AD7188u3-H07     Blood
# 56860  A-NCRD-NC005389   A-NCRD-NC005389-BR-NCR-91M0544u1-B01     Brain
# 56861  A-NCRD-NC005389   A-NCRD-NC005389-BR-NCR-91M0544u2-H08     Brain
# 56862  A-NCRD-NC005389   A-NCRD-NC005389-BR-NCR-91M0544u3-H08     Brain
#
#       ANALYTE_TYPE Sequencing_Center  Sequencing_Platform SAMPLE_USE  \
# 20515          DNA             Broad  Illumina_HiSeq_2000        WGS
# 20521          DNA             Broad  Illumina_HiSeq_2000        WGS
# 20522          DNA             Broad  Illumina_HiSeq_2000        WGS
# 20523          DNA             Broad  Illumina_HiSeq_2000        WGS
# 20527          DNA             Broad  Illumina_HiSeq_2000        WGS
# ...            ...               ...                  ...        ...
# 56858          DNA             USUHS      Illumina_HiSeqX        WGS
# 56859          DNA             USUHS     Illumina_NovaSeq        WGS
# 56860          DNA             USUHS      Illumina_HiSeqX        WGS
# 56861          DNA             USUHS      Illumina_HiSeqX        WGS
# 56862          DNA             USUHS     Illumina_NovaSeq        WGS
#
#        Technical_Replicate Study_DSS Sample_Set
# 20515                    0  sa000001   snd10000
# 20521                    0  sa000001   snd10000
# 20522                    0  sa000001   snd10000
# 20523                    0  sa000001   snd10000
# 20527                    0  sa000001   snd10000
# ...                    ...       ...        ...
# 56858                    1  sa000001   snd10031
# 56859                    1  sa000001   snd10031
# 56860                    1  sa000001   snd10031
# 56861                    1  sa000001   snd10031
# 56862                    1  sa000001   snd10031
#
# [111 rows x 10 columns]

# %%
manifest[manifest.SUBJID == 'A-MIA-UM000037']
# Out:
#                SUBJID                         SampleID BODY_SITE ANALYTE_TYPE  \
# 12868  A-MIA-UM000037  A-MIA-UM000037-UNK-MIA-19890652   Unknown          DNA
# 20515  A-MIA-UM000037   A-MIA-UM000037-BR-MIA-19890652     Brain          DNA
# 37399  A-MIA-UM000037  A-MIA-UM000037-BR-MIA-201307277     Brain          DNA
#
#       Sequencing_Center       Sequencing_Platform SAMPLE_USE  \
# 12868           UM_HIHG  Illumina_HiSeq_2000/2500        WES
# 20515             Broad       Illumina_HiSeq_2000        WGS
# 37399             USUHS          Illumina_NovaSeq        WGS
#
#        Technical_Replicate Study_DSS Sample_Set
# 12868                    0  sa000006   snd10006
# 20515                    0  sa000001   snd10000
# 37399                    0  sa000001   snd10020

# %%
manifest[manifest.SUBJID == 'A-MIA-UM000463']
# Out:
#                SUBJID                           SampleID BODY_SITE  \
# 5969   A-MIA-UM000463    A-ADC-AD002288-BR-NCR-08AD10497     Brain
# 20521  A-MIA-UM000463    A-MIA-UM000463-BR-MIA-201307288     Brain
# 35781  A-MIA-UM000463  A-MIA-UM000463-BR-MIA-201307288uf     Brain
#
#       ANALYTE_TYPE Sequencing_Center  Sequencing_Platform SAMPLE_USE  \
# 5969           DNA             Broad  Illumina_HiSeq_2000        WES
# 20521          DNA             Broad  Illumina_HiSeq_2000        WGS
# 35781          DNA             USUHS     Illumina_NovaSeq        WGS
#
#        Technical_Replicate Study_DSS Sample_Set
# 5969                     0  sa000001   snd10000
# 20521                    0  sa000001   snd10000
# 35781                    0  sa000001   snd10020

# %%
# Only keeping the first row
WGS = dup_notfindinking[dup_notfindinking.SAMPLE_USE == 'WGS'].drop_duplicates(subset= 'SUBJID')
WES = dup_notfindinking[(dup_notfindinking.SAMPLE_USE == 'WES') & (dup_notfindinking.SUBJID.isin(WGS.SUBJID))].drop_duplicates(subset= 'SUBJID')

# %%
# Out:
#                SUBJID                         SampleID BODY_SITE ANALYTE_TYPE  \
# 0      A-ACT-AC000004      A-ACT-AC000004-BL-UPN-15872     Blood          DNA
# 1      A-ACT-AC000007       A-ACT-AC000007-BL-UPN-6888     Blood          DNA
# 2      A-ACT-AC000008       A-ACT-AC000008-BL-UPN-8307     Blood          DNA
# 3      A-ACT-AC000010      A-ACT-AC000010-BL-UWA-15286     Blood          DNA
# 5      A-ACT-AC000015      A-ACT-AC000015-BL-UPN-39345     Blood          DNA
# ...               ...                              ...       ...          ...
# 56840  A-ADC-AD013032  A-ADC-AD013032-BL-NCR-15AD81841     Blood          DNA
# 56841  A-ADC-AD015544  A-ADC-AD015544-BL-NCR-16AD86202     Blood          DNA
# 56842  A-ADC-AD015476  A-ADC-AD015476-BL-NCR-13AD59678     Blood          DNA
# 56843  A-ADC-AD015266  A-ADC-AD015266-BR-NCR-14AD74741     Brain          DNA
# 56844  A-ADC-AD002607  A-ADC-AD002607-BR-NCR-08AD10805     Brain          DNA
#
#       Sequencing_Center  Sequencing_Platform SAMPLE_USE  Technical_Replicate  \
# 0                 WashU  Illumina_HiSeq_2000        WES                    0
# 1                 WashU  Illumina_HiSeq_2000        WES                    0
# 2                 WashU  Illumina_HiSeq_2000        WES                    0
# 3                 WashU  Illumina_HiSeq_2000        WES                    0
# 5                 WashU  Illumina_HiSeq_2000        WES                    0
# ...                 ...                  ...        ...                  ...
# 56840             USUHS     Illumina_NovaSeq        WGS                    0
# 56841             USUHS     Illumina_NovaSeq        WGS                    0
# 56842             USUHS     Illumina_NovaSeq        WGS                    0
# 56843             USUHS     Illumina_NovaSeq        WGS                    0
# 56844             USUHS     Illumina_NovaSeq        WGS                    0
#
#       Study_DSS Sample_Set
# 0      sa000001   snd10000
# 1      sa000001   snd10000
# 2      sa000001   snd10000
# 3      sa000001   snd10000
# 5      sa000001   snd10000
# ...         ...        ...
# 56840  sa000001   snd10031
# 56841  sa000001   snd10031
# 56842  sa000001   snd10031
# 56843  sa000001   snd10031
# 56844  sa000001   snd10031
#
# [31940 rows x 10 columns]

# %%
manifest_merge = pd.concat([manifest.drop_duplicates(subset='SUBJID',keep = False),from_king, WGS, WES])

# %%
pheno_w_sampleID = pheno_merge.merge(manifest_merge)

# %%
pheno_w_sampleID
# Out:
#                 SUBJID  Sex  Age  Age_baseline  APOE_reported  Race  \
# 0      ADNI_002_S_0413    1   87            76             33     5
# 1      ADNI_002_S_0685    1   90            89             33     5
# 2      ADNI_002_S_0729    1   68            65             34     5
# 3      ADNI_002_S_1155    0   69            57             33     5
# 4      ADNI_002_S_1261    1   82            71             33     5
# ...                ...  ...  ...           ...            ...   ...
# 36205  A-CUHS-CU000563    0   74            77             34     6
# 36206  A-CUHS-CU000387    1   87            71             23     6
# 36207  A-CUHS-CU000194    1   73            65             33     6
# 36208  A-CUHS-CU000169    1   87            84             33     5
# 36209  A-CUHS-CU000018    1   76            79             34     6
#
#        Diagnosis        source                            SampleID BODY_SITE  \
# 0              0          ADNI                     ADNI_002_S_0413     Blood
# 1              0          ADNI                     ADNI_002_S_0685     Blood
# 2              1          ADNI                     ADNI_002_S_0729     Blood
# 3              0          ADNI                     ADNI_002_S_1155     Blood
# 4              0          ADNI                     ADNI_002_S_1261     Blood
# ...          ...           ...                                 ...       ...
# 36205          1  case_control     A-CUHS-CU000563-BL-COL-47451BL1     Blood
# 36206          0  case_control     A-CUHS-CU000387-BL-COL-38200BL2     Blood
# 36207          0  case_control     A-CUHS-CU000194-BL-COL-38470BL1     Blood
# 36208          0  case_control  A-CUHS-CU000169-BL-COL-57413BL1dew     Blood
# 36209          1  case_control     A-CUHS-CU000018-BL-COL-46250BL1     Blood
#
#       ANALYTE_TYPE Sequencing_Center  Sequencing_Platform SAMPLE_USE  \
# 0              DNA          Illumina  Illumina_HiSeq_2000        WGS
# 1              DNA          Illumina  Illumina_HiSeq_2000        WGS
# 2              DNA          Illumina  Illumina_HiSeq_2000        WGS
# 3              DNA          Illumina  Illumina_HiSeq_2000        WGS
# 4              DNA          Illumina  Illumina_HiSeq_2000        WGS
# ...            ...               ...                  ...        ...
# 36205          DNA             WashU  Illumina_HiSeq_2000        WES
# 36206          DNA             WashU  Illumina_HiSeq_2000        WES
# 36207          DNA             WashU  Illumina_HiSeq_2000        WES
# 36208          DNA             WashU      Illumina_HiSeqX        WGS
# 36209          DNA             WashU  Illumina_HiSeq_2000        WES
#
#        Technical_Replicate Study_DSS Sample_Set
# 0                        0  sa000002   snd10002
# 1                        0  sa000002   snd10002
# 2                        0  sa000002   snd10002
# 3                        0  sa000002   snd10002
# 4                        0  sa000002   snd10002
# ...                    ...       ...        ...
# 36205                    0  sa000001   snd10000
# 36206                    0  sa000001   snd10000
# 36207                    0  sa000001   snd10000
# 36208                    0  sa000001   snd10001
# 36209                    0  sa000001   snd10000
#
# [36210 rows x 17 columns]

# %%
pheno_w_sampleID.SAMPLE_USE.value_counts()
# Out:
# WGS    21608
# WES    14602
# Name: SAMPLE_USE, dtype: int64

# %%
pheno_w_sampleID.to_csv(path+'pheno_merge_sampleID_king.tsv', sep = '\t', index = False)

# %%
# Out:
#                 SUBJID  Sex  Age  Age_baseline  APOE_reported  Race  \
# 0      ADNI_002_S_0413    1   87            76             33     5
# 1      ADNI_002_S_0685    1   90            89             33     5
# 2      ADNI_002_S_0729    1   68            65             34     5
# 3      ADNI_002_S_1155    0   69            57             33     5
# 4      ADNI_002_S_1261    1   82            71             33     5
# ...                ...  ...  ...           ...            ...   ...
# 36241  A-CUHS-CU000563    0   74            77             34     6
# 36242  A-CUHS-CU000387    1   87            71             23     6
# 36243  A-CUHS-CU000194    1   73            65             33     6
# 36244  A-CUHS-CU000169    1   87            84             33     5
# 36245  A-CUHS-CU000018    1   76            79             34     6
#
#        Diagnosis        source                            SampleID BODY_SITE  \
# 0              0          ADNI                     ADNI_002_S_0413     Blood
# 1              0          ADNI                     ADNI_002_S_0685     Blood
# 2              1          ADNI                     ADNI_002_S_0729     Blood
# 3              0          ADNI                     ADNI_002_S_1155     Blood
# 4              0          ADNI                     ADNI_002_S_1261     Blood
# ...          ...           ...                                 ...       ...
# 36241          1  case_control     A-CUHS-CU000563-BL-COL-47451BL1     Blood
# 36242          0  case_control     A-CUHS-CU000387-BL-COL-38200BL2     Blood
# 36243          0  case_control     A-CUHS-CU000194-BL-COL-38470BL1     Blood
# 36244          0  case_control  A-CUHS-CU000169-BL-COL-57413BL1dew     Blood
# 36245          1  case_control     A-CUHS-CU000018-BL-COL-46250BL1     Blood
#
#       ANALYTE_TYPE Sequencing_Center  Sequencing_Platform SAMPLE_USE  \
# 0              DNA          Illumina  Illumina_HiSeq_2000        WGS
# 1              DNA          Illumina  Illumina_HiSeq_2000        WGS
# 2              DNA          Illumina  Illumina_HiSeq_2000        WGS
# 3              DNA          Illumina  Illumina_HiSeq_2000        WGS
# 4              DNA          Illumina  Illumina_HiSeq_2000        WGS
# ...            ...               ...                  ...        ...
# 36241          DNA             WashU  Illumina_HiSeq_2000        WES
# 36242          DNA             WashU  Illumina_HiSeq_2000        WES
# 36243          DNA             WashU  Illumina_HiSeq_2000        WES
# 36244          DNA             WashU      Illumina_HiSeqX        WGS
# 36245          DNA             WashU  Illumina_HiSeq_2000        WES
#
#        Technical_Replicate Study_DSS Sample_Set
# 0                        0  sa000002   snd10002
# 1                        0  sa000002   snd10002
# 2                        0  sa000002   snd10002
# 3                        0  sa000002   snd10002
# 4                        0  sa000002   snd10002
# ...                    ...       ...        ...
# 36241                    0  sa000001   snd10000
# 36242                    0  sa000001   snd10000
# 36243                    0  sa000001   snd10000
# 36244                    0  sa000001   snd10001
# 36245                    0  sa000001   snd10000
#
# [36246 rows x 17 columns]

# %%
pheno_w_sampleID[~pheno_w_sampleID.SUBJID.isin(pheno_sampleID.SUBJID)]
# Out:
# Empty DataFrame
# Columns: [SUBJID, Sex, Age, Age_baseline, APOE_reported, Race, Diagnosis, source, SampleID, BODY_SITE, ANALYTE_TYPE, Sequencing_Center, Sequencing_Platform, SAMPLE_USE, Technical_Replicate, Study_DSS, Sample_Set]
# Index: []

# %%
pheno_w_sampleID[~pheno_w_sampleID.SampleID.isin(pheno_sampleID.SampleID)]
# Out:
#                 SUBJID  Sex  Age  Age_baseline  APOE_reported  Race  \
# 1595   A-CUHS-CU001167    1   70            65             33     6
# 1655   A-CUHS-CU006133    1   58            58             44     6
# 1700   A-LOAD-LD004371    1   53            53             34     5
# 1743    A-MIA-UM000486    0   67            67             33     5
# 1758    A-MIA-UM001826    1   85            85             33     5
# ...                ...  ...  ...           ...            ...   ...
# 36165   A-MIA-UM000336    1   72            72             34     5
# 36167   A-MIA-UM000329    0   73            73             34     5
# 36169   A-MIA-UM000037    1   74            87             34     5
# 36170   A-MIA-UM000037    1   74            87             34     5
# 36178  A-LOAD-LD002055    0   80            83             33     5
#
#        Diagnosis        source                           SampleID BODY_SITE  \
# 1595           0  Family_based    A-CUHS-CU001167-BL-COL-32167BL1     Blood
# 1655           0  Family_based    A-CUHS-CU006133-BL-COL-31008BL1     Blood
# 1700           0  Family_based  A-LOAD-LD004371-BL-NCR-04AD7188fa     Blood
# 1743           0  Family_based    A-MIA-UM000486-UNK-MIA-19950416   Unknown
# 1758           0  Family_based   A-MIA-UM001826-UNK-MIA-200808817   Unknown
# ...          ...           ...                                ...       ...
# 36165          1  case_control    A-ADC-AD002827-BR-NCR-08AD10512     Brain
# 36167          1  case_control     A-NCRD-NC005342-BL-NCR-91M0044     Blood
# 36169          1  case_control     A-MIA-UM000037-BR-MIA-19890652     Brain
# 36170          1  case_control    A-MIA-UM000037-UNK-MIA-19890652   Unknown
# 36178          1  case_control     A-ADC-AD001821-BR-NCR-08AD7766     Brain
#
#       ANALYTE_TYPE Sequencing_Center       Sequencing_Platform SAMPLE_USE  \
# 1595           DNA            Baylor       Illumina_HiSeq_2000        WGS
# 1655           DNA             WashU           Illumina_HiSeqX        WGS
# 1700           DNA            Baylor           Illumina_HiSeqX        WGS
# 1743           DNA           UM_HIHG  Illumina_HiSeq_2000/2500        WES
# 1758           DNA           UM_HIHG  Illumina_HiSeq_2000/2500        WES
# ...            ...               ...                       ...        ...
# 36165          DNA             Broad       Illumina_HiSeq_2000        WES
# 36167          DNA             WashU       Illumina_HiSeq_2000        WES
# 36169          DNA             Broad       Illumina_HiSeq_2000        WGS
# 36170          DNA           UM_HIHG  Illumina_HiSeq_2000/2500        WES
# 36178          DNA             Broad       Illumina_HiSeq_2000        WES
#
#        Technical_Replicate Study_DSS Sample_Set
# 1595                     1  sa000001   snd10000
# 1655                     0  sa000001   snd10001
# 1700                     1  sa000001   snd10001
# 1743                     0  sa000006   snd10006
# 1758                     0  sa000006   snd10006
# ...                    ...       ...        ...
# 36165                    0  sa000001   snd10000
# 36167                    0  sa000001   snd10000
# 36169                    0  sa000001   snd10000
# 36170                    0  sa000006   snd10006
# 36178                    0  sa000001   snd10000
#
# [440 rows x 17 columns]
