# %%
import pandas as pd
import numpy as np

# import seaborn as sns
# import matplotlib.pyplot as plt

# %%
## load data
# phenotype
path = '/gpfs/commons/groups/knowles_lab/data/ADSP_reguloML/ADSP_vcf/phenotype_file/release_36K/'
ADNI = pd.read_csv(path + "ADNIPhenotypes_DS_2022.08.18_ALL.txt", sep='\t')
family_based = pd.read_csv(path + "ADSPFamilyBasedPhenotypes_DS_2022.08.18_ALL.txt", sep='\t',encoding='cp1252')
case_control = pd.read_csv(path + "ADSPCaseControlPhenotypes_DS_2022.08.18_ALL.txt", sep='\t')
PSPCBD = pd.read_csv(path + "PSPCBDPhenotypes_DS_2022.08.18_ALL.txt", sep='\t')
SUBJ_drop = pd.read_excel(path + 'ng00067_subject_droplist_2022.08.18.xlsx', engine = 'openpyxl')
PSPCBD_descript = pd.read_excel(path + 'PSPCBDPhenotypes_DD_2022.08.18.xlsx', engine = 'openpyxl')

#others
qc = pd.read_csv(path+"gcad.qc.r4.wgs.allchr.36361.GATK.2022.08.15.sample.summary.ALL.txt", sep = '\t') ## this one contains QC info( all the sampleID here are WGS)
ibd = pd.read_csv(path + 'gcad.r4.wgs.36361.2022.08.15.pairwise_IBD.txt', sep = '\t')

vcf = pd.read_csv(path + 'vcf_ids.txt', sep = '\t')
manifest = pd.read_csv(path + "SampleManifest_DS_2022.08.18_ALL.txt", sep='\t') ## the one with mapping info
duplist = pd.read_csv(path + 'duplist.csv') ## the lisan dup IBD list
# Out:
# /gpfs/commons/home/tlin/.conda/envs/polyfun/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Pheno_merge

# %%
## lisan's way
ADNI_processed = ADNI.loc[:,['SUBJID', 'Sex', 'PrevAD', 'IncAD','Age_current', 'Age_MCI_onset','Age_AD_onset', 'Age_baseline','APOE_reported','Race', 'AD_last_visit', 'Ethnicity']]
ADNI_processed["Diagnosis"] = "NaN"
ADNI_processed.loc[(ADNI_processed["PrevAD"] == 1) | (ADNI_processed["IncAD"] ==1),'Diagnosis'] =1
ADNI_processed.loc[(ADNI_processed["PrevAD"] == 0) & (ADNI_processed["IncAD"] ==0) &  (ADNI_processed["Age_MCI_onset"].isnull())& (ADNI_processed["Age_AD_onset"].isnull()),'Diagnosis'] =0

ADNI_processed["Age"] = ADNI_processed.Age_current
ADNI_processed.loc[ADNI_processed.Diagnosis == 1,'Age'] = ADNI_processed.loc[ADNI_processed.Diagnosis == 1,'Age_AD_onset']
#ADNI_processed.loc[ADNI_processed.Diagnosis == 0,'Age'] = ADNI_processed.loc[ADNI_processed.Diagnosis == 1,'Age_current']

ADNI_processed.shape
# Out:
# (1566, 14)

# %%
ADNI_processed.Diagnosis.value_counts()
# Out:
# 1      611
# NaN    525
# 0      430
# Name: Diagnosis, dtype: int64

# %%
ADNI_processed.AD_last_visit.value_counts()
# Out:
# 0    958
# 1    608
# Name: AD_last_visit, dtype: int64

# %%
## check if there are the cases they defined that have AGE_MCI
ADNI_processed[(ADNI_processed.Diagnosis ==1) & (ADNI_processed.Age_MCI_onset.notnull())].shape
# Out:
# (137, 12)

# %%
print(ADNI_processed[ADNI_processed["AD_last_visit"] == 1].shape) 
print(ADNI_processed[ADNI_processed["AD_last_visit"] == 0].shape)

print(ADNI_processed[(ADNI_processed["AD_last_visit"] == 1) & (ADNI_processed["Age_MCI_onset"].notnull())].shape) ## case with MCI info
print(ADNI_processed[(ADNI_processed["AD_last_visit"] == 0) & (ADNI_processed["Age_MCI_onset"].notnull())].shape) ## control with MCI info
print(ADNI_processed[(ADNI_processed["AD_last_visit"] == 0) & (ADNI_processed["Age_MCI_onset"].isnull())].shape)
# Out:
# (608, 12)
# (958, 12)
# (134, 12)
# (528, 12)
# (430, 12)

# %%
## if remove those 528, will be the same as LiSan
ADNI_control[~ADNI_control.SUBJID.isin(ADNI_processed[(ADNI_processed["AD_last_visit"] == 0) & (ADNI_processed["Age_MCI_onset"].isnull())].SUBJID)]
# Out:
# Empty DataFrame
# Columns: [SUBJID, Sex, PrevAD, IncAD, Age_current, Age_MCI_onset, Age_AD_onset, Age_baseline, APOE_reported, Race, AD_last_visit, Diagnosis]
# Index: []

# %%
## The four rows that is inconsistent with AD_last_visit and IncAD
ADNI_case[~ADNI_case.SUBJID.isin(ADNI_processed[ADNI_processed["AD_last_visit"] == 1].SUBJID)]
# Out:
#                SUBJID  Sex  PrevAD  IncAD Age_current Age_MCI_onset  \
# 825   G-ADNI-AN000018    0       0      1          68            59
# 859   G-ADNI-AN000052    1       0      1          75            70
# 981   G-ADNI-AN000176    0       0      1          83            80
# 1276  G-ADNI-AN000478    0       0      1          66            63
#
#      Age_AD_onset Age_baseline  APOE_reported  Race  AD_last_visit Diagnosis
# 825           NaN           60             34   5.0              0         1
# 859           NaN           71             33   5.0              0         1
# 981           NaN           82             34   5.0              0         1
# 1276          NaN           62             33   5.0              0         1

# %%
## But there is a row that in their defination will should be removed but I think its a case (with AD_onset and AD_last_visit)
ADNI_processed[ADNI_processed["AD_last_visit"] == 1][~ADNI_processed[ADNI_processed["AD_last_visit"] == 1].SUBJID.isin(ADNI_case.SUBJID)]
# Out:
#               SUBJID  Sex  PrevAD  IncAD Age_current Age_MCI_onset  \
# 231  ADNI_023_S_4115    0       0      0          75            64
#
#     Age_AD_onset Age_baseline  APOE_reported  Race  AD_last_visit Diagnosis
# 231           75           67             33   5.0              1       NaN

# %%
ADNI_control.SUBJID.isin(ADNI_processed[(ADNI_processed["AD_last_visit"] == 0) & (ADNI_processed["Age_MCI_onset"].isnull())].SUBJID)

# %%
ADNI_processed.head()
# Out:
#             SUBJID  Sex  PrevAD  IncAD Age_current Age_MCI_onset Age_AD_onset  \
# 0  ADNI_002_S_0413    1       0      0          87           NaN          NaN
# 1  ADNI_002_S_0685    1       0      0         90+           NaN          NaN
# 2  ADNI_002_S_0729    1       0      1          72           NaN           68
# 3  ADNI_002_S_1155    0       0      0          69            52          NaN
# 4  ADNI_002_S_1261    1       0      0          82            81          NaN
#
#   Age_baseline  APOE_reported  Race  AD_last_visit  Ethnicity Diagnosis  Age
# 0           76             33   5.0              0        0.0         0   87
# 1           89             33   5.0              0        0.0         0  90+
# 2           65             34   5.0              1        0.0         1   68
# 3           57             33   5.0              0        0.0       NaN   69
# 4           71             33   5.0              0        0.0       NaN   82

# %%
## family_based_lisan
## they are including 8.5k samples that doesnt have diagnosis
family_based = pd.read_csv(path + "ADSPFamilyBasedPhenotypes_DS_2022.08.18_ALL.txt", sep='\t',encoding='cp1252')
family_based['Diagnosis'] = 'NaN'

case = family_based[(family_based['AD'] >=1) & (family_based['AD'] <=3)].copy()
control = family_based[family_based['AD'] == 0].copy()
print('lisan\n case:',case.shape, ', control:',control.shape)

control.loc[:,["Diagnosis"]] = 0
case.loc[:,["Diagnosis"]] = 1
#family_based = pd.concat([control,case])
#family_based_processed = family_based.loc[:, ["SUBJID", "Sex", "Diagnosis", "APOE_reported","Age","Race", "Age_baseline"]]

family_based.loc[(family_based['AD'] >=1) & (family_based['AD'] <=3),'Diagnosis'] = 1
family_based.loc[family_based['AD'] ==0,'Diagnosis'] = 0
family_based_processed = family_based
# Out:
# lisan
#  case: (1858, 28) , control: (2493, 28)

# %%
family_based_processed = family_based
family_based_processed.Diagnosis.value_counts()
# Out:
# NaN    8507
# 0      2493
# 1      1858
# Name: Diagnosis, dtype: int64

# %%
## case_control
case_control_processed = case_control.loc[:,["SUBJID", "Sex", "AD", "APOE_reported","Age","Race", "Age_baseline",'Ethnicity']]
case_control.AD = case_control.AD.astype('Int64')
case_control_processed = case_control_processed.rename(columns = {'AD':'Diagnosis'})
case_control_processed.Diagnosis.value_counts(dropna=False)
# Out:
# 0.0    23347
# 1.0    16793
# NaN     5235
# Name: Diagnosis, dtype: int64

# %%
ADNI_processed["source"] = 'ADNI'
family_based_processed["source"] = 'Family_based'
case_control_processed["source"] = 'case_control'

# %%
pheno = pd.concat([ADNI_processed, family_based_processed, case_control_processed])
pheno.loc[pheno['Age'] == '90+', 'Age'] = 90
pheno.loc[pheno['Age_baseline'] == '90+', 'Age_baseline'] = 90


print(pheno.shape)
print(pheno.Diagnosis.value_counts())
#pheno = pheno.loc[:,['SUBJID','Sex','Age_AD_onset','Age_MCI_onset','Age_baseline','APOE_reported','Race','Diagnosis','source','Ethnicity']]
print(pheno.shape)
# Out:
# (59799, 35)
# 0      26270
# 1      19262
# NaN     9032
# Name: Diagnosis, dtype: int64
# (59799, 35)

# %% [markdown]
# ## deal with duplication

# %%
wgs_SUBJID = manifest[manifest.SampleID.isin(qc.SampleID)].SUBJID
wgs_SUBJID.shape
# Out:
# (36361,)

# %%
print(manifest[(manifest.SUBJID.isin(wgs_SUBJID)) & manifest.SAMPLE_USE == 'WES'])
print(manifest.SAMPLE_USE.value_counts())
# Out:
# Empty DataFrame
# Columns: [SUBJID, SampleID, BODY_SITE, ANALYTE_TYPE, Sequencing_Center, Sequencing_Platform, SAMPLE_USE, Technical_Replicate, Study_DSS, Sample_Set]
# Index: []
# WGS    36361
# WES    20502
# Name: SAMPLE_USE, dtype: int64

# %%
print('before extracting WGS', pheno.shape)
pheno = pheno[pheno.SUBJID.isin(wgs_SUBJID)]

print('After extracting WGS', pheno.shape)
# Out:
# before extracting WGS (59799, 35)
# After extracting WGS (33639, 35)

# %%
## overlaps in Family and Case control, keep the one in Family
print(pheno[(pheno.SUBJID.isin(pheno[pheno.SUBJID.duplicated()].SUBJID)) & (pheno.source == 'case_control')].shape)
pheno[pheno.SUBJID.duplicated()]
pheno = pheno[~pheno.SUBJID.duplicated()] ## only keep family study like they suggest
# Out:
# (32, 35)

# %%
## drop technique replicates (using subjid)
replicate_to_drop = manifest[(manifest.SampleID.isin(qc.SampleID)) & (manifest.Technical_Replicate == 1)] ##(63,10)
pheno[pheno.SUBJID.isin(replicate_to_drop.SUBJID)]
pheno = pheno[~pheno.SUBJID.isin(replicate_to_drop.SUBJID)]
#pheno.to_csv(path + 'check_pheno.tsv',sep = '\t', index = False)
pheno.shape
# Out:
# (33601, 35)

# %% [markdown]
# ## QC sample (deal with the not 1-1 matching in pheno file)
# merge sampleID with SUBJID using manifest file. for those SUBJID that have multiple SampleIDs, pick the one with the lowest missing rate (qc file)

# %%
pheno_add_SampleID  = pheno.merge(manifest, on="SUBJID")
print(pheno_add_SampleID.shape)
dup_sample = pheno_add_SampleID[pheno_add_SampleID.SUBJID.duplicated(keep=False)] #9033 row

dup_SampleID = manifest[manifest.SUBJID.isin(dup_sample.SUBJID.unique())].SampleID ##9033
print(qc[qc.SampleID.isin(dup_SampleID)].Missing.idxmin())
dup_SampleID[~dup_SampleID.isin(qc.SampleID)]  ## not every SampleID is found in QC file

# %%
## extract the SampleID with the lowest missing num
best_SampleID=[]
for i in dup_sample.SUBJID.unique():
    SampleID = manifest[manifest.SUBJID==i].SampleID
    best_id = qc[qc.SampleID.isin(SampleID)].Missing.idxmin()
    best_SampleID.append(qc.loc[best_id].SampleID)

# %%
dup_remove = dup_sample[~dup_sample.SampleID.isin(best_SampleID)]
print(dup_remove.shape) ## 4532 rows to remove
pheno_add_SampleID = pheno_add_SampleID[~pheno_add_SampleID.SampleID.isin(dup_remove.SampleID)] ## remove 4532 rows, 33,601 rows remain

pheno_add_SampleID.to_csv(path + 'pheno_SampleID.tsv',sep = '\t', index = False)
# Out:
# (4532, 44)

# %% [markdown]
# ## Deal with non-concordant phenotype based on APOE status and AD

# %%
pheno_add_SampleID = pd.read_csv(path + 'pheno_SampleID.tsv',sep = '\t')
# Out:
# /gpfs/commons/home/tlin/.conda/envs/polyfun/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (4,5,6,15,16,17,23,24,25,27,30) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
### 1. Deal with IBD
## mapping SampleID to SUBJID
ibdpair_95 = ibd[ibd.PI_HAT>.95]
mapping = manifest.loc[(manifest['SampleID'].isin(ibdpair_95.SampleID1)) | (manifest['SampleID'].isin(ibdpair_95.SampleID2)),['SUBJID','SampleID']]
map_dict = dict(list(zip(mapping.SampleID, mapping.SUBJID)))

ibdpair_95[ibdpair_95.SampleID1.isin(manifest.SampleID)] ## all are found

## Add SUBJID to IBD pair
ibdpair_95.loc[:,['SUBJID1']] = ibdpair_95['SampleID1'].map(map_dict)
ibdpair_95.loc[:,['SUBJID2']] = ibdpair_95['SampleID2'].map(map_dict)
ibdpair_95
# Out:
# /gpfs/commons/home/tlin/.conda/envs/polyfun/lib/python3.6/site-packages/pandas/core/indexing.py:659: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[k] = np.nan
# /gpfs/commons/home/tlin/.conda/envs/polyfun/lib/python3.6/site-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
#                             SampleID1                          SampleID2  \
# 3217  A-LOAD-LD004376-BL-NCR-04AD6509    A-LOAD-LD004376-UNK-UNK-UNK0036
# 3218  A-ADC-AD008841-BL-NCR-10AD24304  G-KGAD-KA000206-UNK-WU-8005874212
# 3219  A-ADC-AD016717-BL-NCR-13AD63111  A-ADC-AD016717-BL-NCR-13AD63111uf
# 3220  A-LOAD-LD004379-BL-NCR-08AD9443    A-LOAD-LD004379-UNK-UNK-UNK0037
# 3221  A-CUHS-CU009833-BL-COL-55252BL1  A-CUHS-CU009833-BL-COL-55252BL1ld
# ...                               ...                                ...
# 4811      P-UCLA-LA000059-UNK-UPN-F03       P-UCSF-PSP10538-UNK-UPN-8882
# 4812      P-UCLA-LA000137-UNK-UPN-E03       P-UPN-PSP10085-BL-UPN-112194
# 4813      P-UCLA-LA000207-UNK-UPN-B11       P-UPN-PSP10065-BL-UPN-104130
# 4814  P-UCLA-LA000394-UNK-UPN-1000016      P-UCSF-PSP10540-UNK-UPN-10886
# 4815       P-UPN-PSP8397-UNK-UPN-2214      P-UPN-PSP10695-UNK-UPN-108077
#
#       PI_HAT          SUBJID1          SUBJID2
# 3217  0.9834  A-LOAD-LD004376  A-LOAD-LD004376
# 3218  0.9897   A-ADC-AD008841  G-KGAD-KA000206
# 3219  0.9914   A-ADC-AD016717   A-ADC-AD016717
# 3220  0.9924  A-LOAD-LD004379  A-LOAD-LD004379
# 3221  0.9927  A-CUHS-CU009833  A-CUHS-CU009833
# ...      ...              ...              ...
# 4811  1.0000  P-UCLA-LA000059  P-UCSF-PSP10538
# 4812  1.0000  P-UCLA-LA000137   P-UPN-PSP10085
# 4813  1.0000  P-UCLA-LA000207   P-UPN-PSP10065
# 4814  1.0000  P-UCLA-LA000394  P-UCSF-PSP10540
# 4815  1.0000   P-UPN-PSP10695   P-UPN-PSP10695
#
# [1599 rows x 5 columns]

# %%
## these are not duplicates from the same SUBJECT but the pi_hat is high 
dup_ibd = ibdpair_95[ibdpair_95.SUBJID1 != ibdpair_95.SUBJID2] ## 513
dup_ibd = dup_ibd[(dup_ibd.SUBJID1.isin(pheno_add_SampleID.SUBJID)) & (dup_ibd.SUBJID2.isin(pheno_add_SampleID.SUBJID))] #458 (They used & instead of | here), if use |, is #477

## check if this is the same as lisan's list
pd.concat([dup_ibd,duplist.iloc[:,[0,1,2,3,4]]]).drop_duplicates(keep=False) ## dup_ibd is exactly the same as duplist
# Out:
# Empty DataFrame
# Columns: [SampleID1, SampleID2, PI_HAT, SUBJID1, SUBJID2]
# Index: []

# %%
## Check if both SUBJID were found pheno_merge

## double check prunedEarlier1 and prunedEarlier2
## The one they listed as Pruned Earlier1 were all found in pheno 
## but they reported 10 and 9 for the not found ones

print(duplist[duplist.Choice == 'PrunedEarlier1'].shape)
print(pheno_add_SampleID[pheno_add_SampleID.SUBJID.isin(duplist[duplist.Choice == 'PrunedEarlier1'].SUBJID1)].shape) ## all were found
print(pheno_add_SampleID[pheno_add_SampleID.SUBJID.isin(duplist[duplist.Choice == 'PrunedEarlier1'].SUBJID2)].shape) ## double check the opposite one just in case


print(duplist[duplist.Choice == 'PrunedEarlier2'].shape)
print(pheno_add_SampleID[pheno_add_SampleID.SUBJID.isin(duplist[duplist.Choice == 'PrunedEarlier2'].SUBJID2)].shape) ## all were found
print(pheno_add_SampleID[pheno_add_SampleID.SUBJID.isin(duplist[duplist.Choice == 'PrunedEarlier2'].SUBJID1)].shape) ## double check the opposite one just in case
# Out:
# (10, 6)
# (10, 44)
# (10, 44)
# (9, 6)
# (9, 44)
# (9, 44)

# %%
## only deal with the columns that they handle manually
dup_ibd_merge = dup_ibd.merge(pheno_add_SampleID, left_on = 'SUBJID1',right_on = 'SUBJID')
dup_ibd_merge = dup_ibd_merge.merge(pheno_add_SampleID, left_on = 'SUBJID2',right_on = 'SUBJID')

# %%
## Remove the rows that inconsistent with AD diagnosis or APOE status ## 136 rows in total
inconsistent = dup_ibd_merge[(dup_ibd_merge.Diagnosis_x != dup_ibd_merge.Diagnosis_y) | 
                            (dup_ibd_merge.APOE_reported_x != dup_ibd_merge.APOE_reported_y)]
#inconsistent = inconsistent[(inconsistent.Diagnosis_x.notnull()) | (inconsistent.Diagnosis_y.notnull())]
print(inconsistent.shape)
dup_ibd_merge = pd.concat([dup_ibd_merge,inconsistent]).drop_duplicates(keep=False) ## only keep the dup_ibd_merge not in inconsistent

#dup_ibd_merge.shape
# Out:
# (138, 93)

# %%
## the two rows we dropped but they didnt(?

## base on their defination, they will drop if
##(1) both NA or 
##(2) one is NA one have info

check_inconsistent = duplist[duplist.Choice == 'Inconsistent']
inconsistent[~inconsistent.SampleID1.isin(check_inconsistent.SampleID1)]
# Out:
#                              SampleID1                        SampleID2  \
# 155  A-ADC-AD016640-BL-NCR-14AD70496uf  A-WCAP-WC001612-BL-COL-49158BL1
# 387   A-ADC-AD015732-BL-NCR-17AD90732e  A-ADC-AD015740-BL-NCR-18AD92097
#
#      PI_HAT         SUBJID1          SUBJID2        SUBJID_x  Sex_x  PrevAD_x  \
# 155     1.0  A-ADC-AD016640  A-WCAP-WC001612  A-ADC-AD016640    0.0       NaN
# 387     1.0  A-ADC-AD015732   A-ADC-AD015740  A-ADC-AD015732    0.0       NaN
#
#      IncAD_x Age_current_x  ... Correction_y                       SampleID_y  \
# 155      NaN           NaN  ...          NaN  A-WCAP-WC001612-BL-COL-49158BL1
# 387      NaN           NaN  ...          NaN  A-ADC-AD015740-BL-NCR-18AD92097
#
#      BODY_SITE_y  ANALYTE_TYPE_y  Sequencing_Center_y  Sequencing_Platform_y  \
# 155        Blood             DNA               Baylor        Illumina_HiSeqX
# 387        Blood             DNA                USUHS       Illumina_NovaSeq
#
#      SAMPLE_USE_y  Technical_Replicate_y  Study_DSS_y Sample_Set_y
# 155           WGS                      0     sa000001     snd10001
# 387           WGS                      0     sa000001     snd10020
#
# [2 rows x 93 columns]

# %%
duplist.value_counts('Choice')
# Out:
# Choice
# Select2           156
# Select1           147
# Inconsistent      136
# PrunedEarlier1     10
# PrunedEarlier2      9
# dtype: int64

# %%
## Check the age  ## no null needs to be drop
dup_ibd_merge[(dup_ibd_merge.Age_x.isnull()) & (dup_ibd_merge.Age_y.isnull())]
# Out:
# Empty DataFrame
# Columns: [SampleID1, SampleID2, PI_HAT, SUBJID1, SUBJID2, SUBJID_x, Diagnosis_x, Race_x, APOE_reported_x, Ethnicity_x, Sex_x, Age_x, SUBJID_y, Diagnosis_y, Race_y, APOE_reported_y, Ethnicity_y, Sex_y, Age_y]
# Index: []

# %%
## chose the older age, if equal, choose the first one
## but why arent they consider the diagnosis!!
dup_ibd_merge[dup_ibd_merge.Age_x == dup_ibd_merge.Age_y].shape

dup_ibd_merge[["Age_x","Age_y"]] = dup_ibd_merge[["Age_x","Age_y"]].fillna(-1)
dup_ibd_merge['Age'] = dup_ibd_merge[["Age_x","Age_y"]].apply(max,axis = 1)

dup_ibd_merge.loc[dup_ibd_merge.Age_x >= dup_ibd_merge.Age_y,'SUBJID']=dup_ibd_merge.SUBJID1
dup_ibd_merge.loc[dup_ibd_merge.Age_x < dup_ibd_merge.Age_y,'SUBJID']=dup_ibd_merge.SUBJID2

dup_ibd_merge.loc[dup_ibd_merge.Age_x >= dup_ibd_merge.Age_y,'SampleID']=dup_ibd_merge.SampleID1
dup_ibd_merge.loc[dup_ibd_merge.Age_x < dup_ibd_merge.Age_y,'SampleID']=dup_ibd_merge.SampleID2

dup_ibd_merge.loc[:,['SUBJID1','SUBJID2','Diagnosis_x','Diagnosis_y','Age_x','Age_y','Age','SUBJID','SampleID']]
# Out:
#              SUBJID1          SUBJID2  Diagnosis_x  Diagnosis_y  Age_x  Age_y  \
# 0     A-ADC-AD008841  G-KGAD-KA000206          1.0          1.0   54.0   55.0
# 1     A-ADC-AD010154  ADNI_011_S_0023          0.0          0.0   81.0   79.0
# 2     A-MIA-UM011643  ADNI_011_S_0023          0.0          0.0   85.0   79.0
# 3     A-ADC-AD010154   A-MIA-UM011643          0.0          0.0   81.0   85.0
# 4     A-ADC-AD005494   A-VAN-VU001340          1.0          1.0   65.0   65.0
# ..               ...              ...          ...          ...    ...    ...
# 452  A-NMAS-NM000498  A-WCAP-WC001585          0.0          0.0   80.0   81.0
# 453  A-NMAS-NM000567  A-WCAP-WC001376          0.0          0.0   77.0   78.0
# 455  A-NMAS-NM000756  A-WCAP-WC001622          0.0          0.0   75.0   76.0
# 456  A-NMAS-NM000760  A-WCAP-WC001573          0.0          0.0   76.0   76.0
# 457  ADNI_011_S_2274  G-KGAD-KA000086          1.0          1.0   65.0   60.0
#
#       Age           SUBJID                           SampleID
# 0    55.0  G-KGAD-KA000206  G-KGAD-KA000206-UNK-WU-8005874212
# 1    81.0   A-ADC-AD010154    A-ADC-AD010154-BL-NCR-13AD63381
# 2    85.0   A-MIA-UM011643    A-MIA-UM011643-BL-MIA-202014718
# 3    85.0   A-MIA-UM011643    A-MIA-UM011643-BL-MIA-202014718
# 4    65.0   A-ADC-AD005494  A-ADC-AD005494-BL-NCR-09AD17556uf
# ..    ...              ...                                ...
# 452  81.0  A-WCAP-WC001585    A-WCAP-WC001585-BL-COL-45991BL1
# 453  78.0  A-WCAP-WC001376    A-WCAP-WC001376-BL-COL-39666BL1
# 455  76.0  A-WCAP-WC001622    A-WCAP-WC001622-BL-COL-50921BL1
# 456  76.0  A-NMAS-NM000760   A-NMAS-NM000760-BL-MIA-200810732
# 457  65.0  ADNI_011_S_2274                    ADNI_011_S_2274
#
# [320 rows x 9 columns]

# %%
## we chose 161 from the firt SUBJID, 159 from 2nd SUBJID
print(dup_ibd_merge[dup_ibd_merge.SUBJID==dup_ibd_merge.SUBJID1].shape) 
print(dup_ibd_merge[dup_ibd_merge.SUBJID==dup_ibd_merge.SUBJID2].shape)
# Out:
# (161, 22)
# (159, 22)

# %%
##diff chose 1
diff_chose_1 = dup_ibd_merge[dup_ibd_merge.SUBJID==dup_ibd_merge.SUBJID1][~dup_ibd_merge[dup_ibd_merge.SUBJID==dup_ibd_merge.SUBJID1].SUBJID.isin(duplist[duplist.Choice =='Select1'].SUBJID1)][['SampleID1','SampleID2','Age','Age_x','Age_y','Diagnosis_x','SampleID']]
diff_chose_1
# Out:
#                              SampleID1                          SampleID2  \
# 2      A-MIA-UM011643-BL-MIA-202014718                    ADNI_011_S_0023
# 60     A-ADC-AD011812-BL-NCR-13AD63377  G-KGAD-KA001183-UNK-WU-8038741747
# 80   A-ADC-AD005696-BL-NCR-09AD19801uf  G-KGAD-KA001276-UNK-WU-8042257841
# 86    A-ADC-AD006858-BL-NCR-09AD16022e    G-ADNI-AN000667-BL-NCR-08AD6948
# 206  A-ADC-AD005361-BL-NCR-09AD18586uf    A-MIA-UM011656-BL-MIA-202014712
# 207  A-ADC-AD005505-BL-NCR-09AD18523uf    A-MIA-UM011662-BL-MIA-202014714
# 279    A-ADC-AD010830-BL-NCR-13AD60193   G-KGAD-KA001014-BL-WU-8038741019
# 284    A-ADC-AD011080-BL-NCR-12ad52213  G-KGAD-KA001089-UNK-WU-8038741135
# 305    A-ADC-AD012245-BL-NCR-13AD63389   G-KGAD-KA001153-BL-WU-8038741692
# 346    A-ADC-AD014631-BL-NCR-13AD60239   G-KGAD-KA001186-BL-WU-8038741616
# 352    A-ADC-AD014801-BL-NCR-11AD39208  G-KGAD-KA001124-UNK-WU-8038741792
# 362    A-ADC-AD015052-BL-NCR-17AD88200    A-MIA-UM011670-BL-MIA-202014693
#
#       Age  Age_x  Age_y  Diagnosis_x                           SampleID
# 2    85.0   85.0   79.0          0.0    A-MIA-UM011643-BL-MIA-202014718
# 184   A-ADC-AD002116-BR-NCR-08AD8064    A-WCAP-WC001247-BL-COL-37101BL1
# 185   A-ADC-AD002153-BR-NCR-08AD8288     A-MIA-UM000037-BR-MIA-19890652
# 186   A-ADC-AD002153-BR-NCR-08AD8288    A-MIA-UM000037-BR-MIA-201307277
# 187  A-ADC-AD002736-BR-NCR-08AD11170  A-MIA-UM000477-BR-MIA-201307292uf
# 354  A-ADC-AD014937-BL-NCR-17AD87680   G-ADNI-AN000107-BL-NCR-12AD53381
# 384  A-ADC-AD015658-BL-NCR-11AD34464   G-ADNI-AN000150-BL-NCR-12AD54510
#
#      PI_HAT         SUBJID1          SUBJID2          Choice
# 39   0.9996  A-ADC-AD015658  G-KGAD-KA000058         Select2
# 45   0.9997  A-ADC-AD001697   A-MIA-UM000320         Select1
# 68   0.9999  A-ADC-AD002736   A-MIA-UM000477         Select1
# 136  0.9999  A-ADC-AD014937   A-MIA-UM011666         Select2
# 184  1.0000  A-ADC-AD002116  A-WCAP-WC001247         Select1
# 185  1.0000  A-ADC-AD002153   A-MIA-UM000037         Select1
# 186  1.0000  A-ADC-AD002153   A-MIA-UM000037  PrunedEarlier2
# 187  1.0000  A-ADC-AD002736   A-MIA-UM000477  PrunedEarlier2
# 354  1.0000  A-ADC-AD014937  G-ADNI-AN000107  PrunedEarlier1
# 384  1.0000  A-ADC-AD015658  G-ADNI-AN000150  PrunedEarlier1

# %%
dup_ibd_merge = dup_ibd_merge.rename(columns = {'Sex_x':'Sex','Ethnicity_x':'Ethnicity','Race_x':'Race'})
print(dup_ibd_merge[['Sex','Ethnicity','Race']].isnull().sum())
dup_ibd_merge.Ethnicity =dup_ibd_merge.Ethnicity.combine_first(dup_ibd_merge.Ethnicity_y)
# Out:
# Sex          0
# Ethnicity    1
# Race         0
# dtype: int64

# %%
# Replace 'col' with 'column' in all column names
dup_ibd_merge = dup_ibd_merge.drop(columns=['Age_x','SUBJID_x','SampleID_x'])
dup_ibd_merge = dup_ibd_merge.rename(columns={col: col.replace('_x', '') for col in dup_ibd_merge.columns})

# %%
duplist[duplist.SUBJID1=='A-MIA-UM011643']
# Out:
#                            SampleID1        SampleID2  PI_HAT         SUBJID1  \
# 160  A-MIA-UM011643-BL-MIA-202014718  ADNI_011_S_0023  0.9999  A-MIA-UM011643
#
#              SUBJID2          Choice
# 160  ADNI_011_S_0023  PrunedEarlier2

# %%
duplist[duplist.SUBJID2=='A-MIA-UM011643']
# Out:
#                          SampleID1                        SampleID2  PI_HAT  \
# 2  A-ADC-AD010154-BL-NCR-13AD63381  A-MIA-UM011643-BL-MIA-202014718  0.9953
#
#           SUBJID1         SUBJID2   Choice
# 2  A-ADC-AD010154  A-MIA-UM011643  Select2

# %%
pheno_add_SampleID[pheno_add_SampleID.SUBJID=='A-ADC-AD010154']
# Out:
#               SUBJID  Sex  PrevAD  IncAD Age_current Age_MCI_onset  \
# 6798  A-ADC-AD010154  0.0     NaN    NaN         NaN           NaN
#
#      Age_AD_onset  Age_baseline  APOE_reported  Race  ...  Correction  \
# 424  G-ADNI-AN000295  1.0     NaN    NaN         NaN           NaN
#
#     Age_AD_onset  Age_baseline  APOE_reported  Race  ...  Correction  \
# 2            NaN          71.0           33.0   4.0  ...         NaN
# 3            NaN           NaN           33.0   4.0  ...         NaN
# 41            72          68.0           34.0   5.0  ...         NaN
# 42           NaN           NaN           34.0   5.0  ...         NaN
# 70           NaN           NaN           23.0   5.0  ...         NaN
# 71           NaN           NaN           23.0   5.0  ...         NaN
# 81           NaN           NaN           34.0   5.0  ...         NaN
# 82           NaN           NaN           34.0   5.0  ...         NaN
# 85           NaN           NaN           34.0   5.0  ...         NaN
# 87           NaN          72.0           34.0   5.0  ...         0.0
# 131          NaN           NaN           34.0   5.0  ...         NaN
# 132          NaN           NaN           34.0   5.0  ...         NaN
# 142          NaN           NaN           22.0   4.0  ...         NaN
# 144          NaN          79.0           22.0   4.0  ...         NaN
# 159          NaN           NaN           34.0   5.0  ...         NaN
# 160          NaN           NaN           34.0   5.0  ...         NaN
# 179          NaN           NaN           34.0   5.0  ...         NaN
# 180          NaN           NaN           34.0   5.0  ...         NaN
# 187          NaN           NaN           33.0   5.0  ...         NaN
# 188          NaN           NaN           33.0   5.0  ...         NaN
# 191          NaN           NaN           34.0   5.0  ...         NaN
# 192          NaN           NaN           34.0   5.0  ...         NaN
# 309          NaN           NaN           33.0   5.0  ...         NaN
# 310          NaN           NaN           33.0   5.0  ...         NaN
# 376          NaN           NaN           44.0   5.0  ...         NaN
# 377          NaN           NaN           44.0   5.0  ...         NaN
# 396          NaN           NaN           34.0   5.0  ...         NaN
# 397          NaN           NaN           34.0   5.0  ...         NaN
# 403          NaN           NaN           34.0   6.0  ...         NaN
# 404          NaN           NaN           34.0   6.0  ...         NaN
# 418          NaN           NaN           34.0   5.0  ...         NaN
# 419          NaN           NaN           34.0   5.0  ...         NaN
# 423          NaN           NaN           34.0   5.0  ...         NaN
# 424          NaN           NaN           34.0   5.0  ...         NaN
#
#                               SampleID  BODY_SITE  ANALYTE_TYPE  \
# 2      A-MIA-UM011643-BL-MIA-202014718      Blood           DNA
# 3      A-MIA-UM011643-BL-MIA-202014718      Blood           DNA
# 41    G-ADNI-AN000150-BL-NCR-12AD54510      Blood           DNA
# 42    G-ADNI-AN000150-BL-NCR-12AD54510      Blood           DNA
# 70     A-MIA-UM000477-BR-MIA-201307292      Brain           DNA
# 71   A-MIA-UM000477-BR-MIA-201307292uf      Brain           DNA
# 81     A-ADC-AD005802-BL-NCR-12AD58301      Blood           DNA
# 82     A-ADC-AD005802-BL-NCR-12AD58301      Blood           DNA
# 85     A-LOAD-LD001253-UNK-UNK-UNK0017      Blood           DNA
# 87     A-LOAD-LD001253-UNK-UNK-UNK0017    Unknown           DNA
# 131                    ADNI_031_S_4024      Blood           DNA
# 132                    ADNI_031_S_4024      Blood           DNA
# 142    A-MIA-UM011666-BL-MIA-202014690      Blood           DNA
# 144    A-MIA-UM011666-BL-MIA-202014690      Blood           DNA
# 159    A-ADC-AD017150-BL-NCR-11AD37917      Blood           DNA
# 160  A-ADC-AD017150-BL-NCR-11AD37917uf      Blood           DNA
# 179     A-ADC-AD000492-BR-NCR-08AD9077      Brain           DNA
# 180    A-ADC-AD000492-BR-NCR-08AD9077g      Brain           DNA
# 187     A-ADC-AD001482-BR-NCR-08AD9124      Brain           DNA
# 188     A-ADC-AD001482-BR-NCR-08AD9124      Brain           DNA
# 191     A-MIA-UM000037-BR-MIA-19890652      Brain           DNA
# 192    A-MIA-UM000037-BR-MIA-201307277      Brain           DNA
# 309   G-ADNI-AN000341-BL-NCR-14AD72055      Blood           DNA
# 310   G-ADNI-AN000341-BL-NCR-14AD72055      Blood           DNA
# 376   G-ADNI-AN000379-BL-NCR-11AD41939      Brain           DNA
# 377   G-ADNI-AN000379-BL-NCR-11AD41939      Brain           DNA
# 396    A-ADC-AD016398-BL-NCR-13AD64639      Blood           DNA
# 397  A-ADC-AD016398-BL-NCR-13AD64639uf      Blood           DNA
# 403    A-ADC-AD016615-BL-NCR-13AD59652      Blood           DNA
# 404  A-ADC-AD016615-BL-NCR-13AD59652uf      Blood           DNA
# 418   G-ADNI-AN000261-BL-NCR-13AD63123      Blood           DNA
# 419   G-ADNI-AN000261-BL-NCR-13AD63123      Blood           DNA
# 423   G-ADNI-AN000295-BL-NCR-13AD65098      Blood           DNA
# 424   G-ADNI-AN000295-BL-NCR-13AD65098      Blood           DNA
#
#     Sequencing_Center  Sequencing_Platform SAMPLE_USE Technical_Replicate  \
# 2               USUHS     Illumina_NovaSeq        WGS                   0
# 3               WashU      Illumina_HiSeqX        WGS                   0
# 41              USUHS     Illumina_NovaSeq        WGS                   0
# 42              USUHS     Illumina_NovaSeq        WGS                   0
# 70              USUHS      Illumina_HiSeqX        WGS                   0
# 71              USUHS      Illumina_HiSeqX        WGS                   0
# 81              USUHS      Illumina_HiSeqX        WGS                   0
# 82              USUHS      Illumina_HiSeqX        WGS                   0
# 85              USUHS     Illumina_NovaSeq        WGS                   0
# 87          GENENTECH  Illumina_HiSeq_2000        WGS                   0
# 131             USUHS      Illumina_HiSeqX        WGS                   0
# 132             USUHS      Illumina_HiSeqX        WGS                   0
# 142             USUHS     Illumina_NovaSeq        WGS                   0
# 144             USUHS     Illumina_NovaSeq        WGS                   0
# 159             USUHS     Illumina_NovaSeq        WGS                   0
# 160             USUHS     Illumina_NovaSeq        WGS                   0
# 179             USUHS      Illumina_HiSeqX        WGS                   0
# 180             USUHS      Illumina_HiSeqX        WGS                   0
# 187             USUHS      Illumina_HiSeqX        WGS                   0
# 188             USUHS      Illumina_HiSeqX        WGS                   0
# 191             USUHS      Illumina_HiSeqX        WGS                   0
# 192             USUHS      Illumina_HiSeqX        WGS                   0
# 309             USUHS      Illumina_HiSeqX        WGS                   0
# 310             USUHS      Illumina_HiSeqX        WGS                   0
# 376             USUHS     Illumina_NovaSeq        WGS                   0
# 377             USUHS     Illumina_NovaSeq        WGS                   0
# 396             USUHS     Illumina_NovaSeq        WGS                   0
# 397             USUHS     Illumina_NovaSeq        WGS                   0
# 403             USUHS     Illumina_NovaSeq        WGS                   0
# 404             USUHS     Illumina_NovaSeq        WGS                   0
# 418             USUHS     Illumina_NovaSeq        WGS                   0
# 419             USUHS     Illumina_NovaSeq        WGS                   0
# 423             USUHS     Illumina_NovaSeq        WGS                   0
# 424             USUHS     Illumina_NovaSeq        WGS                   0
#
#      Study_DSS  Sample_Set
# 2     sa000001    snd10031
# 3     sa000001    snd10001
# 41    sa000001    snd10020
# 42    sa000001    snd10031
# 70    sa000001    snd10020
# 71    sa000001    snd10020
# 81    sa000001    snd10020
# 82    sa000001    snd10020
# 85    sa000023    snd10032
# 87    sa000004    snd10018
# 131   sa000001    snd10020
# 132   sa000001    snd10020
# 142   sa000001    snd10020
# 144   sa000001    snd10031
# 159   sa000001    snd10031
# 160   sa000001    snd10031
# 179   sa000001    snd10020
# 180   sa000001    snd10020
# 187   sa000001    snd10020
# 188   sa000001    snd10020
# 191   sa000001    snd10020
# 192   sa000001    snd10020
# 309   sa000001    snd10020
# 310   sa000001    snd10020
# 376   sa000001    snd10031
# 377   sa000001    snd10031
# 396   sa000001    snd10031
# 397   sa000001    snd10031
# 403   sa000023    snd10032
# 404   sa000023    snd10032
# 418   sa000001    snd10031
# 419   sa000001    snd10031
# 423   sa000001    snd10031
# 424   sa000001    snd10031
#
# [34 rows x 44 columns]

# %%
duplist = pd.read_csv(path + 'duplist.csv') ## the lisan dup IBD list
duplist[['SampleID','SUBJID']] = 'NaN'
duplist.loc[(duplist.Choice == 'Select1')| (duplist.Choice == 'PrunedEarlier2') , 'SampleID'] = duplist.SampleID1
duplist.loc[(duplist.Choice == 'Select2')| (duplist.Choice == 'PrunedEarlier1') , 'SampleID'] = duplist.SampleID2

duplist.loc[(duplist.Choice == 'Select1')| (duplist.Choice == 'PrunedEarlier2') , 'SUBJID'] = duplist.SUBJID1
duplist.loc[(duplist.Choice == 'Select2')| (duplist.Choice == 'PrunedEarlier1') , 'SUBJID'] =  duplist.SUBJID2

# %%
duplist[(duplist.Choice != 'Inconsistent') & (duplist.SUBJID.duplicated(keep=False))].sort_values('SUBJID')
# Out:
#                              SampleID1                          SampleID2  \
# 174    A-ADC-AD000492-BR-NCR-08AD9077g  G-KGAD-KA000111-UNK-WU-8038741595
# 173     A-ADC-AD000492-BR-NCR-08AD9077  G-KGAD-KA000111-UNK-WU-8038741595
# 182     A-ADC-AD001482-BR-NCR-08AD9124  A-MIA-UM001937-BR-MIA-201307284uf
# 181     A-ADC-AD001482-BR-NCR-08AD9124    A-MIA-UM001937-BR-MIA-201307284
# 186     A-ADC-AD002153-BR-NCR-08AD8288    A-MIA-UM000037-BR-MIA-201307277
# 185     A-ADC-AD002153-BR-NCR-08AD8288     A-MIA-UM000037-BR-MIA-19890652
# 187    A-ADC-AD002736-BR-NCR-08AD11170  A-MIA-UM000477-BR-MIA-201307292uf
# 68     A-ADC-AD002736-BR-NCR-08AD11170    A-MIA-UM000477-BR-MIA-201307292
# 78     A-ADC-AD005802-BL-NCR-12AD58301   A-ADC-AD005802
# 396  A-ADC-AD016398-BL-NCR-13AD64639uf   A-ADC-AD016398
# 395    A-ADC-AD016398-BL-NCR-13AD64639   A-ADC-AD016398
# 403  A-ADC-AD016615-BL-NCR-13AD59652uf   A-ADC-AD016615
# 402    A-ADC-AD016615-BL-NCR-13AD59652   A-ADC-AD016615
# 151  A-ADC-AD017150-BL-NCR-11AD37917uf   A-ADC-AD017150
# 150    A-ADC-AD017150-BL-NCR-11AD37917   A-ADC-AD017150
# 81     A-LOAD-LD001253-UNK-UNK-UNK0017  A-LOAD-LD001253
# 155    A-LOAD-LD001253-UNK-UNK-UNK0017  A-LOAD-LD001253
# 2      A-MIA-UM011643-BL-MIA-202014718   A-MIA-UM011643
# 160    A-MIA-UM011643-BL-MIA-202014718   A-MIA-UM011643
# 161    A-MIA-UM011666-BL-MIA-202014690   A-MIA-UM011666
# 136    A-MIA-UM011666-BL-MIA-202014690   A-MIA-UM011666
# 126                    ADNI_031_S_4024  ADNI_031_S_4024
# 125                    ADNI_031_S_4024  ADNI_031_S_4024
# 384   G-ADNI-AN000150-BL-NCR-12AD54510  G-ADNI-AN000150
# 44    G-ADNI-AN000150-BL-NCR-12AD54510  G-ADNI-AN000150
# 418   G-ADNI-AN000261-BL-NCR-13AD63123  G-ADNI-AN000261
# 419   G-ADNI-AN000261-BL-NCR-13AD63123  G-ADNI-AN000261
# 423   G-ADNI-AN000295-BL-NCR-13AD65098  G-ADNI-AN000295
# 424   G-ADNI-AN000295-BL-NCR-13AD65098  G-ADNI-AN000295
# 306   G-ADNI-AN000341-BL-NCR-14AD72055  G-ADNI-AN000341
# 307   G-ADNI-AN000341-BL-NCR-14AD72055  G-ADNI-AN000341
# 374   G-ADNI-AN000379-BL-NCR-11AD41939  G-ADNI-AN000379
# 375   G-ADNI-AN000379-BL-NCR-11AD41939  G-ADNI-AN000379

# %%
duplist[(duplist.Choice == 'Select1') | (duplist.Choice=='Select2')].shape
# Out:
# (303, 8)

# %%
pheno_not_dup = pheno_add_SampleID[~(pheno_add_SampleID.SUBJID.isin(dup_ibd_merge.SUBJID1)) & ~(pheno_add_SampleID.SUBJID.isin(dup_ibd_merge.SUBJID2))]

# %%
pheno_solve_ibd = pd.concat([pheno_not_dup,dup_ibd_merge])

# %% [markdown]
# ### last step, family filter

# %%
pheno_solve_ibd .value_counts("source")
# Out:
# source
# case_control    30765
# ADNI             1449
# Family_based     1105
# dtype: int64

# %%
family = pheno_solve_ibd[pheno_solve_ibd.source=='Family_based']  ## they have 1114

# %%
pheno_solve_ibd[pheno_solve_ibd.source=='Family_based'].FamID.unique().shape ### they have 276
# Out:
# (273,)

# %%
# Randomly shuffle the rows of the DataFrame
families = family.sample(frac=1)
# Group the DataFrame by FamID and select the row with the highest DX_harmonized value (chose the case)
one_per_fam = families.sort_values(by='Diagnosis', ascending=False)\
                     .groupby('FamID', sort=False)\
                     .head(1)\
                     .reset_index(drop=True)

# %%
pheno_fin = pd.concat([pheno_solve_ibd[pheno_solve_ibd.source!='Family_based'],one_per_fam])

# %%
pheno_fin.shape
# Out:
# (32487, 93)

# %%
pheno_fin
# Out:
#               SUBJID  Sex  PrevAD  IncAD Age_current Age_MCI_onset  \
# 1    ADNI_002_S_0685  1.0     0.0    0.0         90+           NaN
# 3    ADNI_002_S_1155  0.0     0.0    0.0          69            52
# 4    ADNI_002_S_1261  1.0     0.0    0.0          82            81
# 7    ADNI_002_S_2010  1.0     0.0    0.0          68           NaN
# 8    ADNI_002_S_2043  1.0     0.0    0.0          73            67
# ..               ...  ...     ...    ...         ...           ...
# 268  A-LOAD-LD001011  0.0     NaN    NaN         NaN           NaN
# 269  A-WRAP-WR001209  1.0     NaN    NaN         NaN           NaN
# 270  A-LOAD-LD004299  1.0     NaN    NaN         NaN           NaN
# 271   A-MIA-UM009911  0.0     NaN    NaN         NaN           NaN
# 272  A-LOAD-LD001312  1.0     NaN    NaN         NaN           NaN
#
#     Age_AD_onset  Age_baseline  APOE_reported  Race  ...  Correction_y  \
# 1            NaN          89.0           33.0   5.0  ...           NaN
# 3            NaN          57.0           33.0   5.0  ...           NaN
# 4            NaN          71.0           33.0   5.0  ...           NaN
# 7            NaN          62.0           34.0   6.0  ...           NaN
# 8            NaN          72.0           34.0   5.0  ...           NaN
# ..           ...           ...            ...   ...  ...           ...
# 268          NaN          78.0           44.0   5.0  ...           NaN
# 269          NaN          48.0           34.0   5.0  ...           NaN
# 270          NaN          90.0           23.0   5.0  ...           NaN
# 271          NaN           NaN           34.0   4.0  ...           NaN
# 272          NaN          83.0           44.0   5.0  ...           NaN
#
#      SampleID_y  BODY_SITE_y  ANALYTE_TYPE_y Sequencing_Center_y  \
# 1           NaN          NaN             NaN                 NaN
# 3           NaN          NaN             NaN                 NaN
# 4           NaN          NaN             NaN                 NaN
# 7           NaN          NaN             NaN                 NaN
# 8           NaN          NaN             NaN                 NaN
# ..          ...          ...             ...                 ...
# 268         NaN          NaN             NaN                 NaN
# 269         NaN          NaN             NaN                 NaN
# 270         NaN          NaN             NaN                 NaN
# 271         NaN          NaN             NaN                 NaN
# 272         NaN          NaN             NaN                 NaN
#
#     Sequencing_Platform_y SAMPLE_USE_y Technical_Replicate_y  Study_DSS_y  \
# 1                     NaN          NaN                   NaN          NaN
# 3                     NaN          NaN                   NaN          NaN
# 4                     NaN          NaN                   NaN          NaN
# 7                     NaN          NaN                   NaN          NaN
# 8                     NaN          NaN                   NaN          NaN
# ..                    ...          ...                   ...          ...
# 268                   NaN          NaN                   NaN          NaN
# 269                   NaN          NaN                   NaN          NaN
# 270                   NaN          NaN                   NaN          NaN
# 271                   NaN          NaN                   NaN          NaN
# 272                   NaN          NaN                   NaN          NaN
#
#      Sample_Set_y
# 1             NaN
# 3             NaN
# 4             NaN
# 7             NaN
# 8             NaN
# ..            ...
# 268           NaN
# 269           NaN
# 270           NaN
# 271           NaN
# 272           NaN
#
# [32487 rows x 93 columns]

# %%
pheno_fin = pheno_fin.dropna(subset=['Age','Diagnosis']) #26691

# %%
pheno_fin.shape
# Out:
# (26691, 93)

# %%
pheno_fin[pheno_fin.Age>=65] ## 21260
# Out:
#               SUBJID  Sex  PrevAD  IncAD Age_current Age_MCI_onset  \
# 1    ADNI_002_S_0685  1.0     0.0    0.0         90+           NaN
# 7    ADNI_002_S_2010  1.0     0.0    0.0          68           NaN
# 9    ADNI_002_S_2073  1.0     0.0    0.0          69           NaN
# 10   ADNI_002_S_4171  0.0     0.0    1.0          71           NaN
# 13   ADNI_002_S_4225  0.0     0.0    0.0          74           NaN
# ..               ...  ...     ...    ...         ...           ...
# 257  A-CUHS-CU009816  1.0     NaN    NaN         NaN           NaN
# 258  A-CUHS-CU004510  1.0     NaN    NaN         NaN           NaN
# 260  A-WRAP-WR000963  1.0     NaN    NaN         NaN           NaN
# 261  A-CUHS-CU001445  0.0     NaN    NaN         NaN           NaN
# 262  A-LOAD-LD002831  0.0     NaN    NaN         NaN           NaN
#
#     Age_AD_onset  Age_baseline  APOE_reported  Race  ...  Correction_y  \
# 1            NaN          89.0           33.0   5.0  ...           NaN
# 7            NaN          62.0           34.0   6.0  ...           NaN
# 9            NaN          63.0           33.0   5.0  ...           NaN
# 10            71          69.0           33.0   5.0  ...           NaN
# 13           NaN          70.0           34.0   5.0  ...           NaN
# ..           ...           ...            ...   ...  ...           ...
# 257          NaN          69.0           34.0   5.0  ...           NaN
# 258          NaN          78.0           33.0   6.0  ...           NaN
# 260          NaN          52.0           34.0   5.0  ...           NaN
# 261          NaN          65.0           34.0   6.0  ...           NaN
# 262          NaN          78.0           44.0   5.0  ...           NaN
#
#      SampleID_y  BODY_SITE_y  ANALYTE_TYPE_y Sequencing_Center_y  \
# 1           NaN          NaN             NaN                 NaN
# 7           NaN          NaN             NaN                 NaN
# 9           NaN          NaN             NaN                 NaN
# 10          NaN          NaN             NaN                 NaN
# 13          NaN          NaN             NaN                 NaN
# ..          ...          ...             ...                 ...
# 257         NaN          NaN             NaN                 NaN
# 258         NaN          NaN             NaN                 NaN
# 260         NaN          NaN             NaN                 NaN
# 261         NaN          NaN             NaN                 NaN
# 262         NaN          NaN             NaN                 NaN
#
#     Sequencing_Platform_y SAMPLE_USE_y Technical_Replicate_y  Study_DSS_y  \
# 1                     NaN          NaN                   NaN          NaN
# 7                     NaN          NaN                   NaN          NaN
# 9                     NaN          NaN                   NaN          NaN
# 10                    NaN          NaN                   NaN          NaN
# 13                    NaN          NaN                   NaN          NaN
# ..                    ...          ...                   ...          ...
# 257                   NaN          NaN                   NaN          NaN
# 258                   NaN          NaN                   NaN          NaN
# 260                   NaN          NaN                   NaN          NaN
# 261                   NaN          NaN                   NaN          NaN
# 262                   NaN          NaN                   NaN          NaN
#
#      Sample_Set_y
# 1             NaN
# 7             NaN
# 9             NaN
# 10            NaN
# 13            NaN
# ..            ...
# 257           NaN
# 258           NaN
# 260           NaN
# 261           NaN
# 262           NaN
#
# [21260 rows x 93 columns]
