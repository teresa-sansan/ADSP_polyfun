# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
blk = pd.read_csv('/gpfs/commons/groups/knowles_lab/data/ADSP_reguloML/LD_ADSP36K_4PRScs/count/blk_size_check', sep ='\t', names=['chr','size'])

# %%
blk.plot("chr", "size", linestyle='None', marker='x', markersize=5, color='skyblue', figsize=(20,8))
plt.xticks(blk.chr, fontsize=10)
plt.ylabel('SNP count per LD block', fontsize=14)
plt.show()
